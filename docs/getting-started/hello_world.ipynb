# %% [markdown]
# # Your Guide to Agent-Factory!

# %% [markdown]
# Welcome to your entry point for using Agent-Factory!
#
# This notebook will guide you through the process of creating, running and, perhaps most importantly, evaluating your first agent. As a "[hello-world](https://en.wikipedia.org/wiki/%22Hello,_World!%22_program)" example, we will build an agent that summarizes text content from a given webpage URL. This notebook includes all execution outputs so you can follow along without having to execute it. If you prefer to start fresh and try it yourself, you can select from the Jupyter Notebook's menu: `Edit -> Clear All Outputs`.
#
# But, before we begin:
#
# ### What is Agent-Factory?
#
# Agent-Factory is a framework that enables users to build and deploy AI agents through natural language prompts, lowering the technical barrier of entry for non-AI experts.
#
# ### How does it work?
#
# The main concepts you will need to understand to get you started are:
#
# - **Task**: The high-level description of what you want to achieve with your agent. In this case, we want to summarize text content from a given webpage URL.
#
# - **Manufacturing Agent**: The agent that will help you create your own agents. Think of it as you own personal alchemist-druid! You submit your vision of your ideal minion-assistant that you need help with for a very specific task, and the Manufacturing Agent will fulfill your wish.
#
#   - _In practice:_ A server, running on the background, that receives requests as a natural language prompt, and builds the Target Agent.
#
# - **Target Agent**: The agent that the Manufacturing Agent creates for you, tailored to do the best that it can to complete your task.
# It is a fully functional agent that can be run independently, anywhere you like, and it will have its own set of very specific capabilities and requirements, tailored to the specific task you requested.
#
#   - _In practice:_ A directory containing of Python code (agent.py) that implements the Target Agent, along with all the files necessary for the agent to be successfully run (`tools`, `requirements.txt`, `agent_parameters.json`, etc.).
#
# - **Criteria Agent**: The agent that can help you generate a set of criteria, aka **Evaluation Case**, to evaluate the Target Agent. You can imagine these criteria as a check-list for the Target Agent to ensure that has completed the task you requested as intended. **NOTE:** these criteria can also be manually defined by you. A recommended flow would be that you first generate a set with the Criteria Agent, and then you review and refine them to your needs.
#
#   - _In practice:_ A structured JSON file that contains the evaluation criteria, such as the input data, expected output, and any other relevant information needed to evaluate the Target Agent.
#
# - **Agent Judge**: The agent that will execute the Target Agent against the Evaluation Case and provide a score based on how well it performed. This is the final step to ensure that the Target Agent is capable of completing the task you requested.
#
#   - _In practice:_ The Agent Judge will read through the Target Agent's output (traces) and compare it to all the criteria defined in the Evaluation Case, scoring whether the criteria were met (found in the output) or not.

# %% [markdown]
# ### Installation
#
# Before running this notebook, ensure that you have installed Agent-Factory, by following the instructions in the [Installation Guide](installation.md). Don't forget to also create a .env file with your OpenAI and Tavily API keys, as they are necessary for this notebook.
#
# ### Setup
#
# #### Jupyter Notebook
#
# To start this notebook, in a terminal with the project's virtual environment activated, run:
# ```bash
# uv run --with jupyter jupyter lab
# ```
# and you will now be able to run the commands below from within this notebook.
#
# #### Agent-Factory Server
#
# In another terminal (not inside this notebook), move to the src/agent-factory directory and start the agent-factory server in `--nochat` mode:
#
# ```bash
# cd src/agent_factory && uv run . --host 0.0.0.0 --port 8080 --nochat
# ```
#
# This will prepare the Manufacturing Agent to receive requests and build any Target Agent you ask.
# The `--nochat` flag is used so that the Manufacturing Agent "one-shots" your request, meaning it will not engage in a back-and-forth conversation with you, but rather will try to fulfill your request in one go.

# %% [markdown]
# ### Let's build!

# %%
# Necessary to run the Target Agent within a notebook environment
import nest_asyncio

nest_asyncio.apply()

# %%
# This notebook is in under the /docs directory, so we need to go up one level to run the agent-factory command
# %cd ../../
# Out:
# /home/kostis/MZAI/agent-factory

# %% [markdown]
# Let's ask the Manufacturing Agent to create the Target Agent for us by providing our prompt and an output directory.

# %%
# The --active flag for uv run enables to use the preconfigured active virtual env instead of jupyter's environment
# !uv run --active agent-factory "Summarize text content from a given webpage URL" --output_dir hello_world
# Out:
# /home/kostis/.cache/uv/archive-v0/ai0FxAJZ12K3HLwcdi3Bc/lib/python3.13/site-packages/pydantic/_internal/_fields.py:198: UserWarning: Field name "config_type" in "SequentialAgent" shadows an attribute in parent "BaseAgent"
#   warnings.warn(
# Overriding of current TracerProvider is not allowed
# [08/19/25 19:07:57] INFO     A2AClient initialized.        ]8;id=685506;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py\agent_generator.py]8;;\:]8;id=484109;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py#60\60]8;;\
#                     INFO     Trace will be saved to        ]8;id=339991;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py\agent_generator.py]8;;\:]8;id=188986;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py#61\61]8;;\
#                              0x1ed385d9e4948e7e652631b713b
#                              bb9d5.jsonl
#                     INFO     No request ID provided,          ]8;id=127683;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py\client_utils.py]8;;\:]8;id=425042;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py#58\58]8;;\
#                              generating a new one
#                     INFO     Request ID:                      ]8;id=66044;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py\client_utils.py]8;;\:]8;id=131177;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py#66\66]8;;\
#                              30a8dde2-0e43-4770-a758-b9c2a5d9
#                              2e46
#                     INFO     Manufacturing agent has       ]8;id=669239;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py\agent_generator.py]8;;\:]8;id=65238;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py#74\74]8;;\
#                              received the message and is
#                              processing it.
#
# [08/19/25 19:08:03] INFO     Making a tool call ...        ]8;id=178220;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py\agent_generator.py]8;;\:]8;id=182680;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py#74\74]8;;\
#                              {'gen_ai.operation.name':
#                              'execute_tool',
#                              'gen_ai.tool.name':
#                              'read_file',
#                              'gen_ai.tool.args':
#                              '{"file_name":
#                              "tools/README.md"}'}
#
# [08/19/25 19:08:09] INFO     Making a tool call ...        ]8;id=934130;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py\agent_generator.py]8;;\:]8;id=453535;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py#74\74]8;;\
#                              {'gen_ai.operation.name':
#                              'execute_tool',
#                              'gen_ai.tool.name':
#                              'read_file',
#                              'gen_ai.tool.args':
#                              '{"file_name":
#                              "tools/summarize_text_with_ll
#                              m.py"}'}
#
# [08/19/25 19:08:13] INFO     Making a tool call ...        ]8;id=703842;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py\agent_generator.py]8;;\:]8;id=474653;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py#74\74]8;;\
#                              {'gen_ai.operation.name':
#                              'execute_tool',
#                              'gen_ai.tool.name':
#                              'read_file',
#                              'gen_ai.tool.args':
#                              '{"file_name":
#                              "tools/extract_text_from_mark
#                              down_or_html.py"}'}
#
# [08/19/25 19:08:56] INFO     Manufacturing agent has       ]8;id=319101;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py\agent_generator.py]8;;\:]8;id=209691;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py#74\74]8;;\
#                              completed the assigned task.
#
#                     INFO     {'id':                           ]8;id=820637;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py\client_utils.py]8;;\:]8;id=506081;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py#80\80]8;;\
#                              '30a8dde20e434770a758b9c2a5d92e4
#                              6', 'jsonrpc': '2.0', 'result':
#                              {'contextId':
#                              '7b678b340884489ca9e870a59e96cd4
#                              5', 'final': True, 'kind':
#                              'status-update', 'status':
#                              {'message': {'contextId':
#                              '7b678b340884489ca9e870a59e96cd4
#                              5', 'kind': 'message',
#                              'messageId':
#                              'c56f82d9-b08b-4d12-ac1f-615c381
#                              8f824', 'parts': [{'kind':
#                              'text', 'text': '{"message":"✅
#                              Done! Your agent is
#                              ready!","status":"completed","im
#                              ports":"from tools.visit_webpage
#                              import visit_webpage\\nfrom
#                              tools.extract_text_from_markdown
#                              _or_html import
#                              extract_text_from_markdown_or_ht
#                              ml\\nfrom
#                              tools.summarize_text_with_llm
#                              import
#                              summarize_text_with_llm","agent_
#                              instructions":"You are an
#                              assistant that produces concise,
#                              accurate summaries of webpages
#                              by following this fixed,
#                              step-by-step
#                              workflow:\\n\\nSTEP-1 – Fetch
#                              webpage:\\n• Receive an input
#                              URL from the user.\\n• Call the
#                              `visit_webpage` tool to download
#                              the page as Markdown.\\n• If the
#                              tool returns an error or empty
#                              content, stop the workflow and
#                              output an appropriate message in
#                              the `summary` field.\\n\\nSTEP-2
#                              – Extract plain text:\\n• Pass
#                              the Markdown returned in STEP-1
#                              to
#                              `extract_text_from_markdown_or_h
#                              tml`, with `content_type` set to
#                              \\"md\\", to strip HTML/Markdown
#                              formatting and non-text
#                              elements.\\n• Trim the result to
#                              at most ~3 000 tokens (about 12
#                              000 characters) while keeping
#                              the most informative
#                              parts.\\n\\nSTEP-3 –
#                              Summarize:\\n• Use
#                              `summarize_text_with_llm` with
#                              `summary_length=\\"a concise
#                              paragraph\\"` to create a clear,
#                              self-contained summary that
#                              captures the main ideas,
#                              purpose, and key details of the
#                              page.\\n• The summary must not
#                              hallucinate information or
#                              include content absent from the
#                              source.\\n\\nSTEP-4 – Final
#                              structured output:\\nReturn a
#                              JSON object that matches the
#                              `StructuredOutput` schema with
#                              these fields:\\n  • url – the
#                              original input URL.\\n  •
#                              extracted_text – the trimmed
#                              plain-text content from
#                              STEP-2.\\n  • summary – the
#                              paragraph-length summary from
#                              STEP-3 (or an error message if
#                              earlier steps
#                              failed).\\n\\nGeneral rules:\\n•
#                              Follow the steps in order and do
#                              not skip any.\\n• Use only the
#                              provided tools.\\n• Keep the
#                              language of the summary the same
#                              as the user’s request (default
#                              English).\\n• Do not expose
#                              internal reasoning or tool
#                              outputs except as specified in
#                              the schema.","tools":"TOOLS =
#                              [\\n    visit_webpage,
#                              # fetches webpage content as
#                              Markdown\\n
#                              extract_text_from_markdown_or_ht
#                              ml, # converts Markdown to plain
#                              text\\n
#                              summarize_text_with_llm,
#                              # creates a concise
#                              summary\\n]","mcp_servers":null,
#                              "structured_outputs":"class
#                              StructuredOutput(BaseModel):\\n
#                              url: str = Field(...,
#                              description=\\"The original
#                              webpage URL provided by the
#                              user.\\")\\n    extracted_text:
#                              str = Field(\\n        ...,
#                              description=\\"Plain,
#                              unformatted text extracted from
#                              the webpage, trimmed to roughly
#                              3 000 tokens.\\")\\n    summary:
#                              str = Field(...,
#                              description=\\"A concise
#                              paragraph summarizing the main
#                              content of the
#                              webpage.\\")","cli_args":"url:
#                              str","agent_description":"Fetche
#                              s a webpage, extracts its
#                              textual content, and returns a
#                              concise
#                              summary.","prompt_template":"f\\
#                              "Summarize the main text content
#                              of this webpage:
#                              {url}\\"","readme":"# Webpage →
#                              Summary Agent\\n\\nA
#                              command-line agent that
#                              retrieves any public webpage,
#                              extracts the readable text, and
#                              returns a concise
#                              paragraph-length summary.\\n\\n#
#                              Prerequisites\\n\\n- uv\\n-
#                              mcpd\\n\\n## Install uv\\n\\n-
#                              **macOS / Linux**\\n
#                              ```bash\\n    curl -LsSf
#                              https://astral.sh/uv/install.sh
#                              | sh\\n    ```\\n- **Windows
#                              PowerShell**\\n```powershell\\np
#                              owershell -ExecutionPolicy
#                              ByPass -c \\"irm
#                              https://astral.sh/uv/install.ps1
#                              | iex\\"\\n```\\n\\n#
#                              Configuration\\n\\nSet the
#                              environment variables in the
#                              `.env` file that has been
#                              created for you. Add other
#                              environment variables as needed,
#                              for example, environment
#                              variables for your LLM
#                              provider.\\n\\n# Run the
#                              Agent\\n\\n```bash\\nuv run
#                              --with-requirements
#                              requirements.txt --python 3.13
#                              python agent.py --url
#                              \\"https://example.com\\"\\n```\
#                              \n","dependencies":"any-agent==1
#                              .2.0\\nmcpd>=0.0.1\\nbeautifulso
#                              up4\\nmarkdown\\nlitellm\\npytho
#                              n-dotenv\\nfire\\nrequests"}'}],
#                               'role': 'agent', 'taskId':
#                              '4bdf7359-f05d-4b11-b811-3cb093c
#                              2ca67'}, 'state': 'completed',
#                              'timestamp':
#                              '2025-08-19T16:08:56.630715+00:0
#                              0'}, 'taskId':
#                              '4bdf7359-f05d-4b11-b811-3cb093c
#                              2ca67'}}
#                     INFO     Received response from agent:    ]8;id=708777;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py\client_utils.py]8;;\:]8;id=534936;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py#90\90]8;;\
#                              {'message': '✅ Done! Your agent
#                              is ready!', 'status':
#                              'completed', 'imports': 'from
#                              tools.visit_webpage import
#                              visit_webpage\nfrom
#                              tools.extract_text_from_markdown
#                              _or_html import
#                              extract_text_from_markdown_or_ht
#                              ml\nfrom
#                              tools.summarize_text_with_llm
#                              import summarize_text_with_llm',
#                              'agent_instructions': 'You are
#                              an assistant that produces
#                              concise, accurate summaries of
#                              webpages by following this
#                              fixed, step-by-step
#                              workflow:\n\nSTEP-1 – Fetch
#                              webpage:\n• Receive an input URL
#                              from the user.\n• Call the
#                              `visit_webpage` tool to download
#                              the page as Markdown.\n• If the
#                              tool returns an error or empty
#                              content, stop the workflow and
#                              output an appropriate message in
#                              the `summary` field.\n\nSTEP-2 –
#                              Extract plain text:\n• Pass the
#                              Markdown returned in STEP-1 to
#                              `extract_text_from_markdown_or_h
#                              tml`, with `content_type` set to
#                              "md", to strip HTML/Markdown
#                              formatting and non-text
#                              elements.\n• Trim the result to
#                              at most ~3 000 tokens (about 12
#                              000 characters) while keeping
#                              the most informative
#                              parts.\n\nSTEP-3 – Summarize:\n•
#                              Use `summarize_text_with_llm`
#                              with `summary_length="a concise
#                              paragraph"` to create a clear,
#                              self-contained summary that
#                              captures the main ideas,
#                              purpose, and key details of the
#                              page.\n• The summary must not
#                              hallucinate information or
#                              include content absent from the
#                              source.\n\nSTEP-4 – Final
#                              structured output:\nReturn a
#                              JSON object that matches the
#                              `StructuredOutput` schema with
#                              these fields:\n  • url – the
#                              original input URL.\n  •
#                              extracted_text – the trimmed
#                              plain-text content from
#                              STEP-2.\n  • summary – the
#                              paragraph-length summary from
#                              STEP-3 (or an error message if
#                              earlier steps
#                              failed).\n\nGeneral rules:\n•
#                              Follow the steps in order and do
#                              not skip any.\n• Use only the
#                              provided tools.\n• Keep the
#                              language of the summary the same
#                              as the user’s request (default
#                              English).\n• Do not expose
#                              internal reasoning or tool
#                              outputs except as specified in
#                              the schema.', 'tools': 'TOOLS =
#                              [\n    visit_webpage,
#                              # fetches webpage content as
#                              Markdown\n
#                              extract_text_from_markdown_or_ht
#                              ml, # converts Markdown to plain
#                              text\n
#                              summarize_text_with_llm,
#                              # creates a concise summary\n]',
#                              'mcp_servers': None,
#                              'structured_outputs': 'class
#                              StructuredOutput(BaseModel):\n
#                              url: str = Field(...,
#                              description="The original
#                              webpage URL provided by the
#                              user.")\n    extracted_text: str
#                              = Field(\n        ...,
#                              description="Plain, unformatted
#                              text extracted from the webpage,
#                              trimmed to roughly 3 000
#                              tokens.")\n    summary: str =
#                              Field(..., description="A
#                              concise paragraph summarizing
#                              the main content of the
#                              webpage.")', 'cli_args': 'url:
#                              str', 'agent_description':
#                              'Fetches a webpage, extracts its
#                              textual content, and returns a
#                              concise summary.',
#                              'prompt_template': 'f"Summarize
#                              the main text content of this
#                              webpage: {url}"', 'readme': '#
#                              Webpage → Summary Agent\n\nA
#                              command-line agent that
#                              retrieves any public webpage,
#                              extracts the readable text, and
#                              returns a concise
#                              paragraph-length summary.\n\n#
#                              Prerequisites\n\n- uv\n-
#                              mcpd\n\n## Install uv\n\n-
#                              **macOS / Linux**\n    ```bash\n
#                              curl -LsSf
#                              https://astral.sh/uv/install.sh
#                              | sh\n    ```\n- **Windows
#                              PowerShell**\n```powershell\npow
#                              ershell -ExecutionPolicy ByPass
#                              -c "irm
#                              https://astral.sh/uv/install.ps1
#                              | iex"\n```\n\n#
#                              Configuration\n\nSet the
#                              environment variables in the
#                              `.env` file that has been
#                              created for you. Add other
#                              environment variables as needed,
#                              for example, environment
#                              variables for your LLM
#                              provider.\n\n# Run the
#                              Agent\n\n```bash\nuv run
#                              --with-requirements
#                              requirements.txt --python 3.13
#                              python agent.py --url
#                              "https://example.com"\n```\n',
#                              'dependencies':
#                              'any-agent==1.2.0\nmcpd>=0.0.1\n
#                              beautifulsoup4\nmarkdown\nlitell
#                              m\npython-dotenv\nfire\nrequests
#                              '}
#                     WARNING  Agent Factory output does not     ]8;id=839073;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/mcpd_utils.py\mcpd_utils.py]8;;\:]8;id=869924;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/mcpd_utils.py#174\174]8;;\
#                              contain MCP servers, no related
#                              artifacts will be exported.
#                     INFO     Saving agent artifacts to     ]8;id=859468;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py\agent_generator.py]8;;\:]8;id=971639;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py#86\86]8;;\
#                              hello_world folder on Local
#                              Storage
#                     INFO     Agent files saved to folder           ]8;id=183591;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/storage.py\storage.py]8;;\:]8;id=138395;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/storage.py#37\37]8;;\
#                              generated_workflows/hello_world

# %% [markdown]
# Now that the Target Agent has been created, let's navigate to the directory where it was created and see the files it generated.

# %%
# %cd generated_workflows/hello_world
# Out:
# /home/kostis/MZAI/agent-factory/generated_workflows/hello_world

# %%
# %ls
# Out:
# agent_parameters.json  agent.py  README.md  requirements.txt  tools/

# %% [markdown]
# Next step: let's run it!
#
# We are using `uv` to explicitly define the Python version we want to use, in this case, Python 3.13, which packages to install from the generated requirements.txt file, and,
# finally, the input for the Target Agent, i.e. the URL we want to summarize.

# %%
# !uv run --with-requirements requirements.txt --python 3.13 python agent.py --url https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-access-any-llm-provider/
# Out:
# warning: `VIRTUAL_ENV=/home/kostis/.cache/uv/archive-v0/ai0FxAJZ12K3HLwcdi3Bc` does not match the project environment path `/home/kostis/MZAI/agent-factory/.venv` and will be ignored; use `--active` to target the active environment instead
# /home/kostis/.cache/uv/archive-v0/BdHyb3zlPPhlN0Lk5KVOB/lib/python3.13/site-packages/pydantic/_internal/_fields.py:198: UserWarning: Field name "config_type" in "SequentialAgent" shadows an attribute in parent "BaseAgent"
#   warnings.warn(
# Error connecting to mcpd: Could not retrieve all tool definitions: Error listing servers: HTTPConnectionPool(host='localhost', port=8090): Max retries exceeded with url: /api/v1/servers (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7af5dc6bf380>: Failed to establish a new connection: [Errno 111] Connection refused'))
# ╭──────────────────────────────── CALL_LLM: o3 ────────────────────────────────╮
# │ ╭─ INPUT ──────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "role": "system",                                                    │ │
# │ │     "content": "\nYou are an assistant that produces concise, accurate s │ │
# │ │   },                                                                     │ │
# │ │   {                                                                      │ │
# │ │     "content": "Summarize the main text content of this webpage: https:/ │ │
# │ │     "role": "user"                                                       │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "visit_webpage",                                        │ │
# │ │     "tool.args": "{\"url\":\"https://blog.mozilla.ai/introducing-any-llm │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 857,                                                   │ │
# │ │   "output_tokens": 57,                                                   │ │
# │ │   "input_cost": 0.001714,                                                │ │
# │ │   "output_cost": 0.00045599999999999997                                  │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────── EXECUTE_TOOL: visit_webpage ─────────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "url": "https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-a │ │
# │ │   "timeout": 30,                                                         │ │
# │ │   "max_length": 20000                                                    │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ 🌆 ]8;id=551951;https://blog.mozilla.ai\Mozilla.ai]8;;\ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ │ │
# │ │ ┃ Introducing any-llm: A unified API to access any LLM provider  ]8;id=738265;#/portal/signin\Sign]8;;\  ┃ │ │
# │ │ ┃  ]8;id=847201;#/portal/signin\in]8;;\ ]8;id=305736;#/portal/signup\Subscribe]8;;\ Introducing any-llm: A unified API to access any LLM   ┃ │ │
# │ │ ┃                               provider                               ┃ │ │
# │ │ ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛ │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=474082;/author/nathan/\Nathan Brake]8;;\ When it comes to using LLMs, it’s not always a question  │ │
# │ │ to use: it’s also a matter of choosing who provides the LLM and where it │ │
# │ │ is deployed. Today, we announce the release of any-llm, a Python library │ │
# │ │ that provides a simple unified interface to access the most popular      │ │
# │ │ providers.                                                               │ │
# │ │                                                                          │ │
# │ │                               ]8;id=302494;/author/nathan/\Nathan Brake]8;;\                               │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=568295;/content/images/size/w1200/2025/07/any-llm.jpeg\Introducing any-llm: A unified API to access any LLM provider]8;;\ Jul 22, │ │
# │ │ ]8;id=583514;https://pdimagearchive.org/images/bfb9c099-b4f3-41b2-8b4a-99773d86d7ba/\Tail”, a Zulu fairy tale]8;;\ When it comes to using Large Language Models    │ │
# │ │ (LLMs), it’s not always a question of which model to use: it’s also a    │ │
# │ │ matter of choosing who provides the LLM and where it is deployed. As     │ │
# │ │ ]8;id=991913;https://blog.mozilla.ai/running-an-open-source-llm-in-2025/\we’ve written about previously]8;;\, there are many options available for how │ │
# │ │ to access an LLM. The provider you choose to use can have implications   │ │
# │ │ in terms of cost, latency, and security. Most AI labs offer their own    │ │
# │ │ provider platform (OpenAI, Google, Mistral, etc.), and other provider    │ │
# │ │ platforms (Azure, AWS, Cerebras, etc.) provide access to a wide variety  │ │
# │ │ of LLMs. But what if you want to build your LLM application without      │ │
# │ │ having to worry about being locked in to a certain provider? Today,      │ │
# │ │ we’re happy to announce the release of our new Python library: ]8;id=96449;https://github.com/mozilla-ai/any-llm?ref=blog.mozilla.ai\any-llm]8;;\!  │ │
# │ │ any-llm provides a simple unified interface to access the most popular   │ │
# │ │ providers. By changing only a ]8;id=447818;https://mozilla-ai.github.io/any-llm/quickstart/?ref=blog.mozilla.ai#basic-usage\single configuration parameter]8;;\, you can    │ │
# │ │ easily switch between providers and models.                              │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │  from any_llm import completion                                          │ │
# │ │  import os                                                               │ │
# │ │  # Make sure you have the appropriate environment variable set           │ │
# │ │  assert os.environ.get('MISTRAL_API_KEY')                                │ │
# │ │  # Basic completion                                                      │ │
# │ │  response = completion(                                                  │ │
# │ │      model="mistral/mistral-small-latest", # <provider_id>/<model_id>    │ │
# │ │      messages=[{"role": "user", "content": "Hello!"}]                    │ │
# │ │  )                                                                       │ │
# │ │  print(response.choices[0].message.content)                              │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │ any-llm fills a gap in the LLM provider interface landscape through      │ │
# │ │ several key design principles:                                           │ │
# │ │                                                                          │ │
# │ │  1 Use of provider SDKs: any-llm leverages official provider SDKs when   │ │
# │ │    available, reducing the maintenance burden and ensuring               │ │
# │ │    compatibility.                                                        │ │
# │ │  2 Committed to active maintenance: any-llm is integrated with           │ │
# │ │    ]8;id=725278;https://github.com/mozilla-ai/any-agent?ref=blog.mozilla.ai\any-agent]8;;\, one of our most community-engaged projects, so we're       │ │
# │ │    motivated to maintain it.                                             │ │
# │ │  3 No proxy or gateway server required: no need to set up another        │ │
# │ │    service as a gateway: download the any-llm SDK, and you’re good to    │ │
# │ │    communicate with all the supported providers, without having to send  │ │
# │ │    your data through another third-party provider. You can view the list │ │
# │ │    of our supported providers ]8;id=466792;https://mozilla-ai.github.io/any-llm/providers/?ref=blog.mozilla.ai\here]8;;\. OpenAI API Standard                  │ │
# │ │                                                                          │ │
# │ │ ──────────────────────────────────────────────────────────────────────── │ │
# │ │                                                                          │ │
# │ │   The ]8;id=236711;https://openai.com/index/openai-api/?ref=blog.mozilla.ai\OpenAI API]8;;\ has become the standard for LLM provider interfaces.    │ │
# │ │  Although some providers provide perfect compatibility with the OpenAI   │ │
# │ │    API standard, others (like Mistral, Anthropic, etc.) may slightly     │ │
# │ │     diverge from the OpenAI standard when it comes to expected input     │ │
# │ │ parameters and output values. In order to make it easy to switch between │ │
# │ │  these providers, this creates a need for lightweight wrappers that can  │ │
# │ │  gracefully handle these differences while maintaining as consistent an  │ │
# │ │    interface as possible. any-llm solves this problem by normalizing     │ │
# │ │   outputs to return OpenAI ChatCompletion objects, regardless of which   │ │
# │ │   provider is used under the hood. The objects are returned as OpenAI    │ │
# │ │  Pydantic models, so you can access them just as you would if you were   │ │
# │ │     using the official OpenAI API SDK. You can view the any-llm API      │ │
# │ │   documentation ]8;id=403964;https://mozilla-ai.github.io/any-llm/api/completion/?ref=blog.mozilla.ai\here]8;;\. And to see how it relates to existing solutions,   │ │
# │ │               read on. Shortcomings of Existing Solutions                │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │ Several excellent open-source Python libraries already exist to address  │ │
# │ │ the challenge of interacting with various LLM providers, but each comes  │ │
# │ │    with its own set of limitations. One popular solution, ]8;id=158606;https://github.com/BerriAI/litellm?ref=blog.mozilla.ai\LiteLLM]8;;\, is    │ │
# │ │      highly valued for its wide support of different providers and       │ │
# │ │  modalities, making it a great choice for many developers. However, it   │ │
# │ │  re-implements provider interfaces rather than leveraging SDKs that are  │ │
# │ │    managed and released by the providers themselves. As a result, the    │ │
# │ │  approach can lead to compatibility issues and unexpected modifications  │ │
# │ │  in behavior, making it difficult to keep up with the changes happening  │ │
# │ │ among all the providers. Another option, ]8;id=827431;https://github.com/andrewyng/aisuite/issues?ref=blog.mozilla.ai\AISuite]8;;\, was created by ]8;id=35030;https://www.andrewng.org/?ref=blog.mozilla.ai\Andrew]8;;\  │ │
# │ │  ]8;id=957233;https://www.andrewng.org/?ref=blog.mozilla.ai\NG]8;;\ and offers a clean and modular design. However, it is not actively   │ │
# │ │     maintained (its last release was in December of 2024) and lacks      │ │
# │ │ consistent Python-typed interfaces. Furthermore, many framework-specific │ │
# │ │   solutions, such as those found in ]8;id=606039;https://github.com/agno-agi/agno/tree/main/libs/agno/agno/models?ref=blog.mozilla.ai\Agno]8;;\, either depend on LiteLLM or    │ │
# │ │ implement their own provider integrations. These implementations may be  │ │
# │ │   robust, but are difficult to integrate into other software solutions   │ │
# │ │   since they’re tightly coupled with the software already built around   │ │
# │ │    them. Lastly, proxy/gateway solutions like ]8;id=819824;https://openrouter.ai/?ref=blog.mozilla.ai\OpenRouter]8;;\ and ]8;id=708492;https://github.com/Portkey-AI/portkey-python-sdk?ref=blog.mozilla.ai\Portkey]8;;\     │ │
# │ │ require users to set up a hosted proxy server to act as an intermediary  │ │
# │ │  between their code and the LLM provider. Although this can effectively  │ │
# │ │ abstract away the complicated logic from the developer, it adds an extra │ │
# │ │  layer of complexity and a dependency on external services, which might  │ │
# │ │ not be ideal for all use cases. 💡 We hope that any-llm will prove to be │ │
# │ │ a useful alternative to the already available solutions. Take a look at  │ │
# │ │      our ]8;id=890342;https://github.com/mozilla-ai/any-llm?ref=blog.mozilla.ai\repo]8;;\ and ]8;id=126150;https://mozilla-ai.github.io/any-llm/?ref=blog.mozilla.ai\documentation]8;;\ and give it a try today! Read more       │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=475437;/content/images/size/w600/2025/08/gpt-oss.jpg\Standardized Reasoning Content: A first look at using OpenAI’s ]8;;\       │ │
# │ │ ]8;id=327716;/content/images/size/w600/2025/08/gpt-oss.jpg\gpt-oss on multiple providers using any-llm]8;;\ [                            │ │
# │ │                                                                          │ │
# │ │  Standardized Reasoning Content: A first look at using OpenAI’s gpt-oss  │ │
# │ │                   on multiple providers using any-llm                    │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=119819;/content/images/size/w600/2025/07/WASM-Agents.jpeg\Wasm-agents: AI agents running in your browser]8;;\ After OpenAI’s ChatGPT │ │
# │ │ was the OpenAI Completion API. However, with the new “reasoning models”, │ │
# │ │ a critical piece of the output isn’t handled by that OpenAI              │ │
# │ │ specification, leaving each provider to decide how to handle the new     │ │
# │ │ model capabilities. By Nathan Brake Aug 12,                              │ │
# │ │ 2025](/standardized-reasoning-content-a-first-look-at-using-openais-gpt- │ │
# │ │ oss-on-multiple-providers-using-any-llm/) [                              │ │
# │ │                                                                          │ │
# │ │              Wasm-agents: AI agents running in your browser              │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=682318;/content/images/size/w600/2025/05/RP-P-OB-6835.jpg\Smarter Prompts for Better Responses: Exploring Prompt Optimization ]8;;\  │ │
# │ │ ]8;id=728043;/content/images/size/w600/2025/05/RP-P-OB-6835.jpg\and Interpretability for LLMs]8;;\ One of the main barriers to a wider adopti │ │
# │ │ the dependency on extra tools and frameworks that need to be installed   │ │
# │ │ before the agents can be run. In this post, we show how to write agents  │ │
# │ │ as HTML files, which can just be opened and run in a browser. By Davide  │ │
# │ │ Eynard Jul 3, 2025](/wasm-agents-ai-agents-running-in-your-browser/) [   │ │
# │ │                                                                          │ │
# │ │ Smarter Prompts for Better Responses: Exploring Prompt Optimization and  │ │
# │ │                        Interpretability for LLMs                         │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=871481;/content/images/size/w600/2025/05/Charles-Darwin.jpeg\The Challenge of Choosing the Right LLM]8;;\ Generative AI models are high │ │
# │ │ changes to a prompt or switching between models can lead to different    │ │
# │ │ results. Adding to the complexity, LLMs often act as black-boxes, making │ │
# │ │ it difficult to understand how specific prompts influence their          │ │
# │ │ behavior. By Davide Eynard, Hareesh Bahuleyan, Sandra Antunes May 14,    │ │
# │ │ 2025](/smarter-prompts-for-better-responses-exploring-prompt-optimizatio │ │
# │ │ n-and-interpretability-for-llms/) [                                      │ │
# │ │                                                                          │ │
# │ │                 The Challenge of Choosing the Right LLM                  │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=891843;https://blog.mozilla.ai/content/images/2025/01/mozilla.white-1.png\Mozilla.ai]8;;\ Imagine you could effortlessly navigate the universe of LL │ │
# │ │ knowing which one is the perfect fit for your specific query. Today,     │ │
# │ │ this is a very difficult challenge. So, how do you efficiently manage    │ │
# │ │ and use LLMs for various tasks? This is where LLM Routing emerges as a   │ │
# │ │ crucial strategy. By Dimitris Poulopoulos, Mario David Cariñana Abasolo, │ │
# │ │ Juliana Rodrigues Araújo May 8,                                          │ │
# │ │ 2025](/the-challenge-of-choosing-the-right-llm/)                         │ │
# │ │                                                                          │ │
# │ │  • ]8;id=534722;https://www.mozilla.ai/\mozilla.ai]8;;\ Powered by ]8;id=660419;https://ghost.org/\Ghost]8;;\ Mozilla.ai                                │ │
# │ │                                                                          │ │
# │ │ ──────────────────────────────────────────────────────────────────────── │ │
# │ │ Subscribe to receive updates ]8;id=503855;#/portal/signup\Subscribe]8;;\                                   │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────── CALL_LLM: o3 ────────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "extract_text_from_markdown_or_html",                   │ │
# │ │     "tool.args": "{\"content\":\"Introducing any-llm: A unified API to a │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 3170,                                                  │ │
# │ │   "output_tokens": 2352,                                                 │ │
# │ │   "input_cost": 0.006339999999999999,                                    │ │
# │ │   "output_cost": 0.018816                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭────────────── EXECUTE_TOOL: extract_text_from_markdown_or_html ──────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "content": "Introducing any-llm: A unified API to access any LLM provi │ │
# │ │   "content_type": "md"                                                   │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │ │
# │ │ ┃  Introducing any-llm: A unified API to access any LLM provider Sign  ┃ │ │
# │ │ ┃  in Subscribe Introducing any-llm: A unified API to access any LLM   ┃ │ │
# │ │ ┃                               provider                               ┃ │ │
# │ │ ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛ │ │
# │ │                                                                          │ │
# │ │ When it comes to using LLMs, it’s not always a question of which model   │ │
# │ │ to use: it’s also a matter of choosing who provides the LLM and where it │ │
# │ │ is deployed. Today, we announce the release of any-llm, a Python library │ │
# │ │ that provides a simple unified interface to access the most popular      │ │
# │ │ providers. Nathan Brake Jul 22, 2025 — 3 min read Tom Seidmann-Freud /   │ │
# │ │ “Why the Hare Has No Tail”, a Zulu fairy tale When it comes to using     │ │
# │ │ Large Language Models (LLMs), it’s not always a question of which model  │ │
# │ │ to use: it’s also a matter of choosing who provides the LLM and where it │ │
# │ │ is deployed. As we’ve written about previously , there are many options  │ │
# │ │ available for how to access an LLM. The provider you choose to use can   │ │
# │ │ have implications in terms of cost, latency, and security. Most AI labs  │ │
# │ │ offer their own provider platform (OpenAI, Google, Mistral, etc.), and   │ │
# │ │ other provider platforms (Azure, AWS, Cerebras, etc.) provide access to  │ │
# │ │ a wide variety of LLMs. But what if you want to build your LLM           │ │
# │ │ application without having to worry about being locked in to a certain   │ │
# │ │ provider? Today, we’re happy to announce the release of our new Python   │ │
# │ │ library: any-llm ! any-llm provides a simple unified interface to access │ │
# │ │ the most popular providers. By changing only a single configuration      │ │
# │ │ parameter , you can easily switch between providers and models.          │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │  from any_llm import completion                                          │ │
# │ │  import os Make sure you have the appropriate environment variable set   │ │
# │ │  assert os.environ.get('MISTRAL_API_KEY') Basic completion response =    │ │
# │ │  completion(                                                             │ │
# │ │      model="mistral/mistral-small-latest", # / messages=[{"role":        │ │
# │ │  "user", "content": "Hello!"}]                                           │ │
# │ │  )                                                                       │ │
# │ │  print(response.choices[0].message.content)                              │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │ any-llm fills a gap in the LLM provider interface landscape through      │ │
# │ │ several key design principles:                                           │ │
# │ │                                                                          │ │
# │ │  1 Use of provider SDKs : any-llm leverages official provider SDKs when  │ │
# │ │    available, reducing the maintenance burden and ensuring               │ │
# │ │    compatibility.                                                        │ │
# │ │  2 Committed to active maintenance : any-llm is integrated with          │ │
# │ │    any-agent , one of our most community-engaged projects, so we're      │ │
# │ │    motivated to maintain it.                                             │ │
# │ │  3 No proxy or gateway server required : no need to set up another       │ │
# │ │    service as a gateway: download the any-llm SDK, and you’re good to    │ │
# │ │    communicate with all the supported providers, without having to send  │ │
# │ │    your data through another third-party provider. You can view the list │ │
# │ │    of our supported providers here . OpenAI API Standard The OpenAI API  │ │
# │ │    has become the standard for LLM provider interfaces. Although some    │ │
# │ │    providers provide perfect compatibility with the OpenAI API standard, │ │
# │ │    others (like Mistral, Anthropic, etc.) may slightly diverge from the  │ │
# │ │    OpenAI standard when it comes to expected input parameters and output │ │
# │ │    values. In order to make it easy to switch between these providers,   │ │
# │ │    this creates a need for lightweight wrappers that can gracefully      │ │
# │ │    handle these differences while maintaining as consistent an interface │ │
# │ │    as possible. any-llm solves this problem by normalizing outputs to    │ │
# │ │    return OpenAI ChatCompletion objects, regardless of which provider is │ │
# │ │    used under the hood. The objects are returned as OpenAI Pydantic      │ │
# │ │    models, so you can access them just as you would if you were using    │ │
# │ │    the official OpenAI API SDK. You can view the any-llm API             │ │
# │ │    documentation here . And to see how it relates to existing solutions, │ │
# │ │    read on. Shortcomings of Existing Solutions Several excellent         │ │
# │ │    open-source Python libraries already exist to address the challenge   │ │
# │ │    of interacting with various LLM providers, but each comes with its    │ │
# │ │    own set of limitations. One popular solution, LiteLLM , is highly     │ │
# │ │    valued for its wide support of different providers and modalities,    │ │
# │ │    making it a great choice for many developers. However, it             │ │
# │ │    re-implements provider interfaces rather than leveraging SDKs that    │ │
# │ │    are managed and released by the providers themselves. As a result,    │ │
# │ │    the approach can lead to compatibility issues and unexpected          │ │
# │ │    modifications in behavior, making it difficult to keep up with the    │ │
# │ │    changes happening among all the providers. Another option, AISuite ,  │ │
# │ │    was created by Andrew NG and offers a clean and modular design.       │ │
# │ │    However, it is not actively maintained (its last release was in       │ │
# │ │    December of 2024) and lacks consistent Python-typed interfaces.       │ │
# │ │    Furthermore, many framework-specific solutions, such as those found   │ │
# │ │    in Agno , either depend on LiteLLM or implement their own provider    │ │
# │ │    integrations. These implementations may be robust, but are difficult  │ │
# │ │    to integrate into other software solutions since they’re tightly      │ │
# │ │    coupled with the software already built around them. Lastly,          │ │
# │ │    proxy/gateway solutions like OpenRouter and Portkey require users to  │ │
# │ │    set up a hosted proxy server to act as an intermediary between their  │ │
# │ │    code and the LLM provider. Although this can effectively abstract     │ │
# │ │    away the complicated logic from the developer, it adds an extra layer │ │
# │ │    of complexity and a dependency on external services, which might not  │ │
# │ │    be ideal for all use cases. 💡 We hope that any-llm will prove to be  │ │
# │ │    a useful alternative to the already available solutions. Take a look  │ │
# │ │    at our repo and documentation and give it a try today! Read more ]8;id=656016;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\ ]8;;\    │ │
# │ │    ]8;id=976889;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\Standardized Reasoning Content: A first look at using OpenAI’s ]8;;\       │ │
# │ │    ]8;id=321317;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\gpt-oss on multiple providers using any-llm After OpenAI’s ChatGPT ]8;;\   │ │
# │ │    ]8;id=327503;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\release, the default standard for communication was the OpenAI ]8;;\       │ │
# │ │    ]8;id=199770;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\Completion API. However, with the new “reasoning models”, a critical ]8;;\ │ │
# │ │    ]8;id=659182;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\piece of the output isn’t handled by that OpenAI specification, ]8;;\      │ │
# │ │    ]8;id=231713;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\leaving each provider to decide how to handle the new model ]8;;\          │ │
# │ │    ]8;id=26627;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\capabilities.]8;;\]8;id=456519;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\ ]8;;\]8;id=898383;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\By Nathan Brake]8;;\]8;id=243851;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\ ]8;;\]8;id=32342;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\Aug 12, 2025]8;;\ ]8;id=453645;/wasm-agents-ai-agents-running-in-your-browser/\ Wasm-agents: AI agents ]8;;\   │ │
# │ │    ]8;id=95566;/wasm-agents-ai-agents-running-in-your-browser/\running in your browser One of the main barriers to a wider adoption ]8;;\ │ │
# │ │    ]8;id=261898;/wasm-agents-ai-agents-running-in-your-browser/\of open-source agents is the dependency on extra tools and frameworks]8;;\ │ │
# │ │    ]8;id=599425;/wasm-agents-ai-agents-running-in-your-browser/\that need to be installed before the agents can be run. In this post,]8;;\ │ │
# │ │    ]8;id=683772;/wasm-agents-ai-agents-running-in-your-browser/\we show how to write agents as HTML files, which can just be opened ]8;;\  │ │
# │ │    ]8;id=128673;/wasm-agents-ai-agents-running-in-your-browser/\and run in a browser.]8;;\]8;id=452856;/wasm-agents-ai-agents-running-in-your-browser/\ ]8;;\]8;id=401385;/wasm-agents-ai-agents-running-in-your-browser/\By Davide Eynard]8;;\]8;id=501805;/wasm-agents-ai-agents-running-in-your-browser/\ ]8;;\]8;id=890100;/wasm-agents-ai-agents-running-in-your-browser/\Jul 3, 2025]8;;\ ]8;id=971286;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\ Smarter Prompts ]8;;\  │ │
# │ │    ]8;id=8446;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\for Better Responses: Exploring Prompt Optimization and ]8;;\              │ │
# │ │    ]8;id=33650;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\Interpretability for LLMs Generative AI models are highly sensitive ]8;;\  │ │
# │ │    ]8;id=282629;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\to input phrasing. Even small changes to a prompt or switching ]8;;\       │ │
# │ │    ]8;id=932661;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\between models can lead to different results. Adding to the ]8;;\          │ │
# │ │    ]8;id=390553;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\complexity, LLMs often act as black-boxes, making it difficult to ]8;;\    │ │
# │ │    ]8;id=706452;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\understand how specific prompts influence their behavior.]8;;\]8;id=134202;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\ ]8;;\]8;id=303125;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\By Davide ]8;;\  │ │
# │ │    ]8;id=259823;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\Eynard, Hareesh Bahuleyan, Sandra Antunes]8;;\]8;id=437509;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\ ]8;;\]8;id=639859;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\May 14, 2025]8;;\ ]8;id=202621;/the-challenge-of-choosing-the-right-llm/\ The Challenge]8;;\ │ │
# │ │    ]8;id=245501;/the-challenge-of-choosing-the-right-llm/\of Choosing the Right LLM Imagine you could effortlessly navigate the]8;;\ │ │
# │ │    ]8;id=33083;/the-challenge-of-choosing-the-right-llm/\universe of LLMs, always knowing which one is the perfect fit for ]8;;\    │ │
# │ │    ]8;id=135709;/the-challenge-of-choosing-the-right-llm/\your specific query. Today, this is a very difficult challenge. So, ]8;;\  │ │
# │ │    ]8;id=210936;/the-challenge-of-choosing-the-right-llm/\how do you efficiently manage and use LLMs for various tasks? This is]8;;\ │ │
# │ │    ]8;id=393729;/the-challenge-of-choosing-the-right-llm/\where LLM Routing emerges as a crucial strategy.]8;;\]8;id=279122;/the-challenge-of-choosing-the-right-llm/\ ]8;;\]8;id=39314;/the-challenge-of-choosing-the-right-llm/\By Dimitris ]8;;\         │ │
# │ │    ]8;id=644759;/the-challenge-of-choosing-the-right-llm/\Poulopoulos, Mario David Cariñana Abasolo, Juliana Rodrigues Araújo]8;;\]8;id=61991;/the-challenge-of-choosing-the-right-llm/\ ]8;;\  │ │
# │ │    ]8;id=780302;/the-challenge-of-choosing-the-right-llm/\May 8, 2025]8;;\ * mozilla.ai Powered by Ghost Mozilla.ai Subscribe to     │ │
# │ │    receive updates Subscribe                                             │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Setting attribute on ended span.
# Tried calling set_status on an ended span.
# ╭────────────── EXECUTE_TOOL: extract_text_from_markdown_or_html ──────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "content": "Introducing any-llm: A unified API to access any LLM provi │ │
# │ │   "content_type": "md"                                                   │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │ │
# │ │ ┃  Introducing any-llm: A unified API to access any LLM provider Sign  ┃ │ │
# │ │ ┃  in Subscribe Introducing any-llm: A unified API to access any LLM   ┃ │ │
# │ │ ┃                               provider                               ┃ │ │
# │ │ ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛ │ │
# │ │                                                                          │ │
# │ │ When it comes to using LLMs, it’s not always a question of which model   │ │
# │ │ to use: it’s also a matter of choosing who provides the LLM and where it │ │
# │ │ is deployed. Today, we announce the release of any-llm, a Python library │ │
# │ │ that provides a simple unified interface to access the most popular      │ │
# │ │ providers. Nathan Brake Jul 22, 2025 — 3 min read Tom Seidmann-Freud /   │ │
# │ │ “Why the Hare Has No Tail”, a Zulu fairy tale When it comes to using     │ │
# │ │ Large Language Models (LLMs), it’s not always a question of which model  │ │
# │ │ to use: it’s also a matter of choosing who provides the LLM and where it │ │
# │ │ is deployed. As we’ve written about previously , there are many options  │ │
# │ │ available for how to access an LLM. The provider you choose to use can   │ │
# │ │ have implications in terms of cost, latency, and security. Most AI labs  │ │
# │ │ offer their own provider platform (OpenAI, Google, Mistral, etc.), and   │ │
# │ │ other provider platforms (Azure, AWS, Cerebras, etc.) provide access to  │ │
# │ │ a wide variety of LLMs. But what if you want to build your LLM           │ │
# │ │ application without having to worry about being locked in to a certain   │ │
# │ │ provider? Today, we’re happy to announce the release of our new Python   │ │
# │ │ library: any-llm ! any-llm provides a simple unified interface to access │ │
# │ │ the most popular providers. By changing only a single configuration      │ │
# │ │ parameter , you can easily switch between providers and models.          │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │  from any_llm import completion                                          │ │
# │ │  import os Make sure you have the appropriate environment variable set   │ │
# │ │  assert os.environ.get('MISTRAL_API_KEY') Basic completion response =    │ │
# │ │  completion(                                                             │ │
# │ │      model="mistral/mistral-small-latest", # / messages=[{"role":        │ │
# │ │  "user", "content": "Hello!"}]                                           │ │
# │ │  )                                                                       │ │
# │ │  print(response.choices[0].message.content)                              │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │ any-llm fills a gap in the LLM provider interface landscape through      │ │
# │ │ several key design principles:                                           │ │
# │ │                                                                          │ │
# │ │  1 Use of provider SDKs : any-llm leverages official provider SDKs when  │ │
# │ │    available, reducing the maintenance burden and ensuring               │ │
# │ │    compatibility.                                                        │ │
# │ │  2 Committed to active maintenance : any-llm is integrated with          │ │
# │ │    any-agent , one of our most community-engaged projects, so we're      │ │
# │ │    motivated to maintain it.                                             │ │
# │ │  3 No proxy or gateway server required : no need to set up another       │ │
# │ │    service as a gateway: download the any-llm SDK, and you’re good to    │ │
# │ │    communicate with all the supported providers, without having to send  │ │
# │ │    your data through another third-party provider. You can view the list │ │
# │ │    of our supported providers here . OpenAI API Standard The OpenAI API  │ │
# │ │    has become the standard for LLM provider interfaces. Although some    │ │
# │ │    providers provide perfect compatibility with the OpenAI API standard, │ │
# │ │    others (like Mistral, Anthropic, etc.) may slightly diverge from the  │ │
# │ │    OpenAI standard when it comes to expected input parameters and output │ │
# │ │    values. In order to make it easy to switch between these providers,   │ │
# │ │    this creates a need for lightweight wrappers that can gracefully      │ │
# │ │    handle these differences while maintaining as consistent an interface │ │
# │ │    as possible. any-llm solves this problem by normalizing outputs to    │ │
# │ │    return OpenAI ChatCompletion objects, regardless of which provider is │ │
# │ │    used under the hood. The objects are returned as OpenAI Pydantic      │ │
# │ │    models, so you can access them just as you would if you were using    │ │
# │ │    the official OpenAI API SDK. You can view the any-llm API             │ │
# │ │    documentation here . And to see how it relates to existing solutions, │ │
# │ │    read on. Shortcomings of Existing Solutions Several excellent         │ │
# │ │    open-source Python libraries already exist to address the challenge   │ │
# │ │    of interacting with various LLM providers, but each comes with its    │ │
# │ │    own set of limitations. One popular solution, LiteLLM , is highly     │ │
# │ │    valued for its wide support of different providers and modalities,    │ │
# │ │    making it a great choice for many developers. However, it             │ │
# │ │    re-implements provider interfaces rather than leveraging SDKs that    │ │
# │ │    are managed and released by the providers themselves. As a result,    │ │
# │ │    the approach can lead to compatibility issues and unexpected          │ │
# │ │    modifications in behavior, making it difficult to keep up with the    │ │
# │ │    changes happening among all the providers. Another option, AISuite ,  │ │
# │ │    was created by Andrew NG and offers a clean and modular design.       │ │
# │ │    However, it is not actively maintained (its last release was in       │ │
# │ │    December of 2024) and lacks consistent Python-typed interfaces.       │ │
# │ │    Furthermore, many framework-specific solutions, such as those found   │ │
# │ │    in Agno , either depend on LiteLLM or implement their own provider    │ │
# │ │    integrations. These implementations may be robust, but are difficult  │ │
# │ │    to integrate into other software solutions since they’re tightly      │ │
# │ │    coupled with the software already built around them. Lastly,          │ │
# │ │    proxy/gateway solutions like OpenRouter and Portkey require users to  │ │
# │ │    set up a hosted proxy server to act as an intermediary between their  │ │
# │ │    code and the LLM provider. Although this can effectively abstract     │ │
# │ │    away the complicated logic from the developer, it adds an extra layer │ │
# │ │    of complexity and a dependency on external services, which might not  │ │
# │ │    be ideal for all use cases. 💡 We hope that any-llm will prove to be  │ │
# │ │    a useful alternative to the already available solutions. Take a look  │ │
# │ │    at our repo and documentation and give it a try today! Read more ]8;id=610498;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\ ]8;;\    │ │
# │ │    ]8;id=470465;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\Standardized Reasoning Content: A first look at using OpenAI’s ]8;;\       │ │
# │ │    ]8;id=698399;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\gpt-oss on multiple providers using any-llm After OpenAI’s ChatGPT ]8;;\   │ │
# │ │    ]8;id=681215;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\release, the default standard for communication was the OpenAI ]8;;\       │ │
# │ │    ]8;id=746299;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\Completion API. However, with the new “reasoning models”, a critical ]8;;\ │ │
# │ │    ]8;id=14821;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\piece of the output isn’t handled by that OpenAI specification, ]8;;\      │ │
# │ │    ]8;id=684590;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\leaving each provider to decide how to handle the new model ]8;;\          │ │
# │ │    ]8;id=360825;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\capabilities.]8;;\]8;id=127584;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\ ]8;;\]8;id=924477;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\By Nathan Brake]8;;\]8;id=456603;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\ ]8;;\]8;id=401378;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\Aug 12, 2025]8;;\ ]8;id=602816;/wasm-agents-ai-agents-running-in-your-browser/\ Wasm-agents: AI agents ]8;;\   │ │
# │ │    ]8;id=335223;/wasm-agents-ai-agents-running-in-your-browser/\running in your browser One of the main barriers to a wider adoption ]8;;\ │ │
# │ │    ]8;id=780171;/wasm-agents-ai-agents-running-in-your-browser/\of open-source agents is the dependency on extra tools and frameworks]8;;\ │ │
# │ │    ]8;id=724697;/wasm-agents-ai-agents-running-in-your-browser/\that need to be installed before the agents can be run. In this post,]8;;\ │ │
# │ │    ]8;id=622248;/wasm-agents-ai-agents-running-in-your-browser/\we show how to write agents as HTML files, which can just be opened ]8;;\  │ │
# │ │    ]8;id=290715;/wasm-agents-ai-agents-running-in-your-browser/\and run in a browser.]8;;\]8;id=605088;/wasm-agents-ai-agents-running-in-your-browser/\ ]8;;\]8;id=159874;/wasm-agents-ai-agents-running-in-your-browser/\By Davide Eynard]8;;\]8;id=909658;/wasm-agents-ai-agents-running-in-your-browser/\ ]8;;\]8;id=988790;/wasm-agents-ai-agents-running-in-your-browser/\Jul 3, 2025]8;;\ ]8;id=880443;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\ Smarter Prompts ]8;;\  │ │
# │ │    ]8;id=408;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\for Better Responses: Exploring Prompt Optimization and ]8;;\              │ │
# │ │    ]8;id=235185;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\Interpretability for LLMs Generative AI models are highly sensitive ]8;;\  │ │
# │ │    ]8;id=215896;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\to input phrasing. Even small changes to a prompt or switching ]8;;\       │ │
# │ │    ]8;id=786583;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\between models can lead to different results. Adding to the ]8;;\          │ │
# │ │    ]8;id=852017;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\complexity, LLMs often act as black-boxes, making it difficult to ]8;;\    │ │
# │ │    ]8;id=247987;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\understand how specific prompts influence their behavior.]8;;\]8;id=597900;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\ ]8;;\]8;id=507882;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\By Davide ]8;;\  │ │
# │ │    ]8;id=579243;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\Eynard, Hareesh Bahuleyan, Sandra Antunes]8;;\]8;id=628785;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\ ]8;;\]8;id=386155;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\May 14, 2025]8;;\ ]8;id=16900;/the-challenge-of-choosing-the-right-llm/\ The Challenge]8;;\ │ │
# │ │    ]8;id=733545;/the-challenge-of-choosing-the-right-llm/\of Choosing the Right LLM Imagine you could effortlessly navigate the]8;;\ │ │
# │ │    ]8;id=947831;/the-challenge-of-choosing-the-right-llm/\universe of LLMs, always knowing which one is the perfect fit for ]8;;\    │ │
# │ │    ]8;id=625191;/the-challenge-of-choosing-the-right-llm/\your specific query. Today, this is a very difficult challenge. So, ]8;;\  │ │
# │ │    ]8;id=685245;/the-challenge-of-choosing-the-right-llm/\how do you efficiently manage and use LLMs for various tasks? This is]8;;\ │ │
# │ │    ]8;id=999317;/the-challenge-of-choosing-the-right-llm/\where LLM Routing emerges as a crucial strategy.]8;;\]8;id=984332;/the-challenge-of-choosing-the-right-llm/\ ]8;;\]8;id=390345;/the-challenge-of-choosing-the-right-llm/\By Dimitris ]8;;\         │ │
# │ │    ]8;id=993531;/the-challenge-of-choosing-the-right-llm/\Poulopoulos, Mario David Cariñana Abasolo, Juliana Rodrigues Araújo]8;;\]8;id=153313;/the-challenge-of-choosing-the-right-llm/\ ]8;;\  │ │
# │ │    ]8;id=283979;/the-challenge-of-choosing-the-right-llm/\May 8, 2025]8;;\ * mozilla.ai Powered by Ghost Mozilla.ai Subscribe to     │ │
# │ │    receive updates Subscribe                                             │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Calling end() on an ended span.
# ╭──────────────────────────────── CALL_LLM: o3 ────────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "summarize_text_with_llm",                              │ │
# │ │     "tool.args": "{\"text\":\"Introducing any-llm: A unified API to acce │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 7099,                                                  │ │
# │ │   "output_tokens": 1137,                                                 │ │
# │ │   "input_cost": 0.014197999999999999,                                    │ │
# │ │   "output_cost": 0.009096                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────── EXECUTE_TOOL: summarize_text_with_llm ────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "text": "Introducing any-llm: A unified API to access any LLM provider │ │
# │ │   "summary_length": "a concise paragraph"                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ The any-llm is a newly released Python library that offers a unified API │ │
# │ │ for accessing various Large Language Model (LLM) providers, allowing     │ │
# │ │ users to switch between models and providers with minimal configuration  │ │
# │ │ change. Its design leverages official SDKs from providers, ensuring      │ │
# │ │ compatibility and ease of use without the need for additional proxy      │ │
# │ │ services. By normalizing outputs to return consistent OpenAI             │ │
# │ │ ChatCompletion objects, any-llm addresses the compatibility issues faced │ │
# │ │ by existing libraries. It aims to fill gaps left by current solutions    │ │
# │ │ that are either not actively maintained or impose complexities through   │ │
# │ │ additional layers. As such, any-llm is positioned as a versatile and     │ │
# │ │ user-friendly implementation for LLM application development.            │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Setting attribute on ended span.
# Tried calling set_status on an ended span.
# ╭─────────────────── EXECUTE_TOOL: summarize_text_with_llm ────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "text": "Introducing any-llm: A unified API to access any LLM provider │ │
# │ │   "summary_length": "a concise paragraph"                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ The any-llm is a newly released Python library that offers a unified API │ │
# │ │ for accessing various Large Language Model (LLM) providers, allowing     │ │
# │ │ users to switch between models and providers with minimal configuration  │ │
# │ │ change. Its design leverages official SDKs from providers, ensuring      │ │
# │ │ compatibility and ease of use without the need for additional proxy      │ │
# │ │ services. By normalizing outputs to return consistent OpenAI             │ │
# │ │ ChatCompletion objects, any-llm addresses the compatibility issues faced │ │
# │ │ by existing libraries. It aims to fill gaps left by current solutions    │ │
# │ │ that are either not actively maintained or impose complexities through   │ │
# │ │ additional layers. As such, any-llm is positioned as a versatile and     │ │
# │ │ user-friendly implementation for LLM application development.            │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Calling end() on an ended span.
# Setting attribute on ended span.
# Tried calling set_status on an ended span.
# ╭─────────────────── EXECUTE_TOOL: summarize_text_with_llm ────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "text": "Introducing any-llm: A unified API to access any LLM provider │ │
# │ │   "summary_length": "a concise paragraph"                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ The any-llm is a newly released Python library that offers a unified API │ │
# │ │ for accessing various Large Language Model (LLM) providers, allowing     │ │
# │ │ users to switch between models and providers with minimal configuration  │ │
# │ │ change. Its design leverages official SDKs from providers, ensuring      │ │
# │ │ compatibility and ease of use without the need for additional proxy      │ │
# │ │ services. By normalizing outputs to return consistent OpenAI             │ │
# │ │ ChatCompletion objects, any-llm addresses the compatibility issues faced │ │
# │ │ by existing libraries. It aims to fill gaps left by current solutions    │ │
# │ │ that are either not actively maintained or impose complexities through   │ │
# │ │ additional layers. As such, any-llm is positioned as a versatile and     │ │
# │ │ user-friendly implementation for LLM application development.            │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Calling end() on an ended span.
# ╭──────────────────────────────── CALL_LLM: o3 ────────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "url": "https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-a │ │
# │ │   "extracted_text": "Introducing any-llm: A unified API to access any LL │ │
# │ │   "summary": "Mozilla.ai announces “any-llm,” a Python library that lets │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 8387,                                                  │ │
# │ │   "output_tokens": 1791,                                                 │ │
# │ │   "input_cost": 0.016774,                                                │ │
# │ │   "output_cost": 0.014327999999999999                                    │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# input_cost=$0.039026 + output_cost=$0.042696 = $0.081722
# url='https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-access-any-llm-provider/' extracted_text='Introducing any-llm: A unified API to access any LLM provider Sign in Subscribe Introducing any-llm: A unified API to access any LLM provider\n=============================================================\nWhen it comes to using LLMs, it’s not always a question of which model to use: it’s also a matter of choosing who provides the LLM and where it is deployed. Today, we announce the release of any-llm, a Python library that provides a simple unified interface to access the most popular providers. Nathan Brake Jul 22, 2025\n— 3 min read Tom Seidmann-Freud / “Why the Hare Has No Tail”, a Zulu fairy tale When it comes to using Large Language Models (LLMs), it’s not always a question of which model to use: it’s also a matter of choosing who provides the LLM and where it is deployed. As we’ve written about previously , there are many options available for how to access an LLM. The provider you choose to use can have implications in terms of cost, latency, and security. Most AI labs offer their own provider platform (OpenAI, Google, Mistral, etc.), and other provider platforms (Azure, AWS, Cerebras, etc.) provide access to a wide variety of LLMs. But what if you want to build your LLM application without having to worry about being locked in to a certain provider?\nToday, we’re happy to announce the release of our new Python library: any-llm ! any-llm provides a simple unified interface to access the most popular providers. By changing only a single configuration parameter , you can easily switch between providers and models.\n```\nfrom any_llm import completion\nimport os Make sure you have the appropriate environment variable set assert os.environ.get(\'MISTRAL_API_KEY\') Basic completion response = completion(\n    model="mistral/mistral-small-latest", # / messages=[{"role": "user", "content": "Hello!"}]\n)\nprint(response.choices[0].message.content)\n```\nany-llm fills a gap in the LLM provider interface landscape through several key design principles:\n1. Use of provider SDKs : any-llm leverages official provider SDKs when available, reducing the maintenance burden and ensuring compatibility.\n2. Committed to active maintenance : any-llm is integrated with any-agent , one of our most community-engaged projects, so we\'re motivated to maintain it.\n3. No proxy or gateway server required : no need to set up another service as a gateway: download the any-llm SDK, and you’re good to communicate with all the supported providers, without having to send your data through another third-party provider.\nYou can view the list of our supported providers here .\nOpenAI API Standard The OpenAI API has become the standard for LLM provider interfaces. Although some providers provide perfect compatibility with the OpenAI API standard, others (like Mistral, Anthropic, etc.) may slightly diverge from the OpenAI standard when it comes to expected input parameters and output values.\nIn order to make it easy to switch between these providers, this creates a need for lightweight wrappers that can gracefully handle these differences while maintaining as consistent an interface as possible.\nany-llm solves this problem by normalizing outputs to return OpenAI ChatCompletion objects, regardless of which provider is used under the hood. The objects are returned as OpenAI Pydantic models, so you can access them just as you would if you were using the official OpenAI API SDK.\nYou can view the any-llm API documentation here . And to see how it relates to existing solutions, read on.\nShortcomings of Existing Solutions Several excellent open-source Python libraries already exist to address the challenge of interacting with various LLM providers, but each comes with its own set of limitations.\nOne popular solution, LiteLLM , is highly valued for its wide support of different providers and modalities, making it a great choice for many developers. Howe ...

# %% [markdown]
# Great, this summary is looking pretty good! 🎉
#
# But, how do we know whether the Target Agent actually did what we had in mind? For example, did it actually visit the URL we provided, or did it just hallucinate and completely made up the summary? 🤔
#
# ### Evaluation time!
#
# In order to ensure that our Target Agent acts according to our requirements, we will build an Evaluation Case with certain criteria the Target Agent must meet in order to be considered successful.
# As we mentioned in the beginning, this can be done either manually or automatically from the Criteria Agent.
# To simplify the process, we recommend to first use the Criteria Agent to auto-generate a few relevant criteria for us,
# and if we are not satisfied with the results, we can refine the criteria later.

# %%
# Let's navigate back to the root directory of the project, so we can run the Criteria Agent.
# %cd ../../
# Out:
# /home/kostis/MZAI/agent-factory

# %%
# !uv run --active -m eval.generate_evaluation_case generated_workflows/hello_world
# Out:
# /home/kostis/.cache/uv/archive-v0/ai0FxAJZ12K3HLwcdi3Bc/lib/python3.13/site-packages/pydantic/_internal/_fields.py:198: UserWarning: Field name "config_type" in "SequentialAgent" shadows an attribute in parent "BaseAgent"
#   warnings.warn(
# Secure MCP Filesystem Server running on stdio
# Client does not support MCP Roots, using allowed directories set from server args: [
#   '/home/kostis/MZAI/agent-factory/generated_workflows/hello_world',
#   '/home/kostis/MZAI/agent-factory'
# ]
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ INPUT ──────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "role": "system",                                                    │ │
# │ │     "content": "\nThe generated_workflow_dir is generated_workflows/hell │ │
# │ │   },                                                                     │ │
# │ │   {                                                                      │ │
# │ │     "content": "\n    Read the generated_workflows/hello_world/agent.py  │ │
# │ │     "role": "user"                                                       │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "read_text_file",                                       │ │
# │ │     "tool.args": "{\"path\":\"generated_workflows/hello_world/agent.py\" │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 2527,                                                  │ │
# │ │   "output_tokens": 23,                                                   │ │
# │ │   "input_cost": 0.0050539999999999995,                                   │ │
# │ │   "output_cost": 0.000184                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────── EXECUTE_TOOL: read_text_file ────────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "path": "generated_workflows/hello_world/agent.py"                     │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "type": "text",                                                        │ │
# │ │   "text": "\n# agent.py\n\n# Always used imports\nimport json  # noqa: I │ │
# │ │   "annotations": null,                                                   │ │
# │ │   "meta": null                                                           │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "criteria": [                                                          │ │
# │ │     "Ensure that the agent receives a URL as input and calls the 'visit_ │ │
# │ │     "Verify that if 'visit_webpage' returns an error or empty content, t │ │
# │ │     "Ensure that the agent passes the Markdown content from 'visit_webpa │ │
# │ │     "Check that the agent trims the extracted text to at most approximat │ │
# │ │     "Ensure that the agent calls 'summarize_text_with_llm' using the tri │ │
# │ │     "Verify that the agent does not hallucinate information in the summa │ │
# │ │     "Check that the agent returns a JSON object strictly conforming to t │ │
# │ │     "Ensure that the value of the 'url' field in the output matches the  │ │
# │ │     "Check that the value of the 'extracted_text' field in the output co │ │
# │ │     "Ensure that the value of the 'summary' field in the output is a con │ │
# │ │     "Verify that the agent uses only the specified tools ('visit_webpage │ │
# │ │     "Check that the agent follows all steps in the specified order and d │ │
# │ │     "Verify that the language of the summary matches that of the user's  │ │
# │ │   ],                                                                     │ │
# │ │   "evaluation_case_generation_costs": {                                  │ │
# │ │     "input_cost": 0.0,                                                   │ │
# │ │     "output_cost": 0.0,                                                  │ │
# │ │     "total_cost": 0.0                                                    │ │
# │ │   }                                                                      │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 3966,                                                  │ │
# │ │   "output_tokens": 501,                                                  │ │
# │ │   "input_cost": 0.007932,                                                │ │
# │ │   "output_cost": 0.004007999999999999                                    │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# We can see that the Criteria Agent has created a file called `evaluation_case.json` in the `generated_workflows/hello_world` directory. Let's open it to see the criteria it generated for us.

# %%
import json
from pathlib import Path

with Path.open("generated_workflows/hello_world/evaluation_case.json", "r") as f:
    eval_case = json.load(f)
    print(json.dumps(eval_case["criteria"], indent=4))
# Out:
# [
#     "Ensure that the agent receives a URL as input and calls the 'visit_webpage' tool using this URL to fetch webpage content as Markdown.",
#     "Verify that if 'visit_webpage' returns an error or empty content, the agent stops further steps and sets an appropriate error message in the 'summary' field of the output JSON.",
#     "Ensure that the agent passes the Markdown content from 'visit_webpage' to 'extract_text_from_markdown_or_html', with 'content_type' set to 'md', to extract plain, unformatted text.",
#     "Check that the agent trims the extracted text to at most approximately 3,000 tokens (about 12,000 characters), prioritizing the most informative parts.",
#     "Ensure that the agent calls 'summarize_text_with_llm' using the trimmed plain text with 'summary_length' set to 'a concise paragraph' to generate a summary.",
#     "Verify that the agent does not hallucinate information in the summary and only includes content present in the source webpage.",
#     "Check that the agent returns a JSON object strictly conforming to the StructuredOutput schema with fields: 'url', 'extracted_text', and 'summary', and no additional fields.",
#     "Ensure that the value of the 'url' field in the output matches the original input URL provided by the user.",
#     "Check that the value of the 'extracted_text' field in the output corresponds exactly to the trimmed plain text extracted using the prescribed tool and step.",
#     "Ensure that the value of the 'summary' field in the output is a concise paragraph summarizing the source, or an appropriate error message if prior steps failed.",
#     "Verify that the agent uses only the specified tools ('visit_webpage', 'extract_text_from_markdown_or_html', 'summarize_text_with_llm', or MCP tools if available), and does not invoke any unlisted tools.",
#     "Check that the agent follows all steps in the specified order and does not skip, reorder, or combine them.",
#     "Verify that the language of the summary matches that of the user's input (default English) and does not include internal reasoning or tool output except as specified in the schema."
# ]

# %% [markdown]
# **Remember** that you can edit this file according to you needs! If a certain criteria is not relevant, you can remove it. Or if something is missing, you can just add it to the file.
#
# For our use case, these criteria are looking pretty good, so let's use them as is.
#
# The next step is to run the Agent Judge, which will execute the Target Agent against the Evaluation Case and provide a score based on how well it performed.

# %%
# !uv run --active -m eval.run_generated_agent_evaluation generated_workflows/hello_world
# Out:
# /home/kostis/.cache/uv/archive-v0/ai0FxAJZ12K3HLwcdi3Bc/lib/python3.13/site-packages/pydantic/_internal/_fields.py:198: UserWarning: Field name "config_type" in "SequentialAgent" shadows an attribute in parent "BaseAgent"
#   warnings.warn(
# [08/19/25 19:12:33] INFO     Successfully   ]8;id=655609;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py\run_generated_agent_evaluation.py]8;;\:]8;id=774154;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py#53\53]8;;\
#                              loaded
#                              evaluation
#                              case from:
#                              generated_work
#                              flows/hello_wo
#                              rld/evaluation
#                              _case.json
#                     INFO     Successfully   ]8;id=544767;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py\run_generated_agent_evaluation.py]8;;\:]8;id=286821;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py#56\56]8;;\
#                              loaded agent
#                              trace from:
#                              generated_work
#                              flows/hello_wo
#                              rld/agent_eval
#                              _trace.json
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ INPUT ──────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "role": "system",                                                    │ │
# │ │     "content": "\nYou are a helpful assistant that will be used to evalu │ │
# │ │   },                                                                     │ │
# │ │   {                                                                      │ │
# │ │     "role": "user",                                                      │ │
# │ │     "content": "Ensure that the agent receives a URL as input and calls  │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "get_messages_from_trace",                              │ │
# │ │     "tool.args": "{}"                                                    │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 378,                                                   │ │
# │ │   "output_tokens": 12,                                                   │ │
# │ │   "input_cost": 0.0007559999999999999,                                   │ │
# │ │   "output_cost": 9.6e-05                                                 │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────── EXECUTE_TOOL: get_messages_from_trace ────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {}                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │                                  system                                  │ │
# │ │                                                                          │ │
# │ │ You are an assistant that produces concise, accurate summaries of        │ │
# │ │ webpages by following this fixed, step-by-step workflow:                 │ │
# │ │                                                                          │ │
# │ │ STEP-1 – Fetch webpage: • Receive an input URL from the user. • Call the │ │
# │ │ visit_webpage tool to download the page as Markdown. • If the tool       │ │
# │ │ returns an error or empty content, stop the workflow and output an       │ │
# │ │ appropriate message in the summary field.                                │ │
# │ │                                                                          │ │
# │ │ STEP-2 – Extract plain text: • Pass the Markdown returned in STEP-1 to   │ │
# │ │ extract_text_from_markdown_or_html, with content_type set to "md", to    │ │
# │ │ strip HTML/Markdown formatting and non-text elements. • Trim the result  │ │
# │ │ to at most ~3 000 tokens (about 12 000 characters) while keeping the     │ │
# │ │ most informative parts.                                                  │ │
# │ │                                                                          │ │
# │ │ STEP-3 – Summarize: • Use summarize_text_with_llm with summary_length="a │ │
# │ │ concise paragraph" to create a clear, self-contained summary that        │ │
# │ │ captures the main ideas, purpose, and key details of the page. • The     │ │
# │ │ summary must not hallucinate information or include content absent from  │ │
# │ │ the source.                                                              │ │
# │ │                                                                          │ │
# │ │ STEP-4 – Final structured output: Return a JSON object that matches the  │ │
# │ │ StructuredOutput schema with these fields: • url – the original input    │ │
# │ │ URL. • extracted_text – the trimmed plain-text content from STEP-2. •    │ │
# │ │ summary – the paragraph-length summary from STEP-3 (or an error message  │ │
# │ │ if earlier steps failed).                                                │ │
# │ │                                                                          │ │
# │ │ General rules: • Follow the steps in order and do not skip any. • Use    │ │
# │ │ only the provided tools. • Keep the language of the summary the same as  │ │
# │ │ the user’s request (default English). • Do not expose internal reasoning │ │
# │ │ or tool outputs except as specified in the schema.                       │ │
# │ │                                                                          │ │
# │ │                                   user                                   │ │
# │ │                                                                          │ │
# │ │ Summarize the main text content of this webpage:                         │ │
# │ │ https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-access-any- │ │
# │ │ llm-provider/                                                            │ │
# │ │                                                                          │ │
# │ │                                assistant                                 │ │
# │ │                                                                          │ │
# │ │ [{"tool.name": "visit_webpage", "tool.args":                             │ │
# │ │ "{"url":"https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-ac │ │
# │ │ cess-any-llm-provider/","timeout":30,"max_length":20000}"}]              │ │
# │ │                                                                          │ │
# │ │                                assistant                                 │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=517691;https://blog.mozilla.ai\Mozilla.ai]8;;\ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ │ │
# │ │ ┃ [Tool visit_webpage executed: Introducing any-llm: A unified API to  ┃ │ │
# │ │ ┃  access any LLM provider  ]8;id=767222;#/portal/signin\Sign in]8;;\ ]8;id=652745;#/portal/signup\Subscribe]8;;\ Introducing any-llm: A   ┃ │ │
# │ │ ┃                unified API to access any LLM provider                ┃ │ │
# │ │ ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛ │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=978018;/author/nathan/\Nathan Brake]8;;\ When it comes to using LLMs, it’s not always a question  │ │
# │ │ to use: it’s also a matter of choosing who provides the LLM and where it │ │
# │ │ is deployed. Today, we announce the release of any-llm, a Python library │ │
# │ │ that provides a simple unified interface to access the most popular      │ │
# │ │ providers.                                                               │ │
# │ │                                                                          │ │
# │ │                               ]8;id=588443;/author/nathan/\Nathan Brake]8;;\                               │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=769355;/content/images/size/w1200/2025/07/any-llm.jpeg\Introducing any-llm: A unified API to access any LLM provider]8;;\ Jul 22, │ │
# │ │ ]8;id=580614;https://pdimagearchive.org/images/bfb9c099-b4f3-41b2-8b4a-99773d86d7ba/\Tail”, a Zulu fairy tale]8;;\ When it comes to using Large Language Models    │ │
# │ │ (LLMs), it’s not always a question of which model to use: it’s also a    │ │
# │ │ matter of choosing who provides the LLM and where it is deployed. As     │ │
# │ │ ]8;id=338418;https://blog.mozilla.ai/running-an-open-source-llm-in-2025/\we’ve written about previously]8;;\, there are many options available for how │ │
# │ │ to access an LLM. The provider you choose to use can have implications   │ │
# │ │ in terms of cost, latency, and security. Most AI labs offer their own    │ │
# │ │ provider platform (OpenAI, Google, Mistral, etc.), and other provider    │ │
# │ │ platforms (Azure, AWS, Cerebras, etc.) provide access to a wide variety  │ │
# │ │ of LLMs. But what if you want to build your LLM application without      │ │
# │ │ having to worry about being locked in to a certain provider? Today,      │ │
# │ │ we’re happy to announce the release of our new Python library: ]8;id=700409;https://github.com/mozilla-ai/any-llm?ref=blog.mozilla.ai\any-llm]8;;\!  │ │
# │ │ any-llm provides a simple unified interface to access the most popular   │ │
# │ │ providers. By changing only a ]8;id=960273;https://mozilla-ai.github.io/any-llm/quickstart/?ref=blog.mozilla.ai#basic-usage\single configuration parameter]8;;\, you can    │ │
# │ │ easily switch between providers and models.                              │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │  from any_llm import completion                                          │ │
# │ │  import os                                                               │ │
# │ │  # Make sure you have the appropriate environment variable set           │ │
# │ │  assert os.environ.get('MISTRAL_API_KEY')                                │ │
# │ │  # Basic completion                                                      │ │
# │ │  response = completion(                                                  │ │
# │ │      model="mistral/mistral-small-latest", # <provider_id>/<model_id>    │ │
# │ │      messages=[{"role": "user", "content": "Hello!"}]                    │ │
# │ │  )                                                                       │ │
# │ │  print(response.choices[0].message.content)                              │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │ any-llm fills a gap in the LLM provider interface landscape through      │ │
# │ │ several key design principles:                                           │ │
# │ │                                                                          │ │
# │ │  1 Use of provider SDKs: any-llm leverages official provider SDKs when   │ │
# │ │    available, reducing the maintenance burden and ensuring               │ │
# │ │    compatibility.                                                        │ │
# │ │  2 Committed to active maintenance: any-llm is integrated with           │ │
# │ │    ]8;id=55158;https://github.com/mozilla-ai/any-agent?ref=blog.mozilla.ai\any-agent]8;;\, one of our most community-engaged projects, so we're       │ │
# │ │    motivated to maintain it.                                             │ │
# │ │  3 No proxy or gateway server required: no need to set up another        │ │
# │ │    service as a gateway: download the any-llm SDK, and you’re good to    │ │
# │ │    communicate with all the supported providers, without having to send  │ │
# │ │    your data through another third-party provider. You can view the list │ │
# │ │    of our supported providers ]8;id=738396;https://mozilla-ai.github.io/any-llm/providers/?ref=blog.mozilla.ai\here]8;;\. OpenAI API Standard                  │ │
# │ │                                                                          │ │
# │ │ ──────────────────────────────────────────────────────────────────────── │ │
# │ │                                                                          │ │
# │ │   The ]8;id=513823;https://openai.com/index/openai-api/?ref=blog.mozilla.ai\OpenAI API]8;;\ has become the standard for LLM provider interfaces.    │ │
# │ │  Although some providers provide perfect compatibility with the OpenAI   │ │
# │ │    API standard, others (like Mistral, Anthropic, etc.) may slightly     │ │
# │ │     diverge from the OpenAI standard when it comes to expected input     │ │
# │ │ parameters and output values. In order to make it easy to switch between │ │
# │ │  these providers, this creates a need for lightweight wrappers that can  │ │
# │ │  gracefully handle these differences while maintaining as consistent an  │ │
# │ │    interface as possible. any-llm solves this problem by normalizing     │ │
# │ │   outputs to return OpenAI ChatCompletion objects, regardless of which   │ │
# │ │   provider is used under the hood. The objects are returned as OpenAI    │ │
# │ │  Pydantic models, so you can access them just as you would if you were   │ │
# │ │     using the official OpenAI API SDK. You can view the any-llm API      │ │
# │ │   documentation ]8;id=588105;https://mozilla-ai.github.io/any-llm/api/completion/?ref=blog.mozilla.ai\here]8;;\. And to see how it relates to existing solutions,   │ │
# │ │               read on. Shortcomings of Existing Solutions                │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │ Several excellent open-source Python libraries already exist to address  │ │
# │ │ the challenge of interacting with various LLM providers, but each comes  │ │
# │ │    with its own set of limitations. One popular solution, ]8;id=16827;https://github.com/BerriAI/litellm?ref=blog.mozilla.ai\LiteLLM]8;;\, is    │ │
# │ │      highly valued for its wide support of different providers and       │ │
# │ │  modalities, making it a great choice for many developers. However, it   │ │
# │ │  re-implements provider interfaces rather than leveraging SDKs that are  │ │
# │ │    managed and released by the providers themselves. As a result, the    │ │
# │ │  approach can lead to compatibility issues and unexpected modifications  │ │
# │ │  in behavior, making it difficult to keep up with the changes happening  │ │
# │ │ among all the providers. Another option, ]8;id=686349;https://github.com/andrewyng/aisuite/issues?ref=blog.mozilla.ai\AISuite]8;;\, was created by ]8;id=494155;https://www.andrewng.org/?ref=blog.mozilla.ai\Andrew]8;;\  │ │
# │ │  ]8;id=404490;https://www.andrewng.org/?ref=blog.mozilla.ai\NG]8;;\ and offers a clean and modular design. However, it is not actively   │ │
# │ │     maintained (its last release was in December of 2024) and lacks      │ │
# │ │ consistent Python-typed interfaces. Furthermore, many framework-specific │ │
# │ │   solutions, such as those found in ]8;id=388360;https://github.com/agno-agi/agno/tree/main/libs/agno/agno/models?ref=blog.mozilla.ai\Agno]8;;\, either depend on LiteLLM or    │ │
# │ │ implement their own provider integrations. These implementations may be  │ │
# │ │   robust, but are difficult to integrate into other software solutions   │ │
# │ │   since they’re tightly coupled with the software already built around   │ │
# │ │    them. Lastly, proxy/gateway solutions like ]8;id=692496;https://openrouter.ai/?ref=blog.mozilla.ai\OpenRouter]8;;\ and ]8;id=751642;https://github.com/Portkey-AI/portkey-python-sdk?ref=blog.mozilla.ai\Portkey]8;;\     │ │
# │ │ require users to set up a hosted proxy server to act as an intermediary  │ │
# │ │  between their code and the LLM provider. Although this can effectively  │ │
# │ │ abstract away the complicated logic from the developer, it adds an extra │ │
# │ │  layer of complexity and a dependency on external services, which might  │ │
# │ │ not be ideal for all use cases. 💡 We hope that any-llm will prove to be │ │
# │ │ a useful alternative to the already available solutions. Take a look at  │ │
# │ │      our ]8;id=436575;https://github.com/mozilla-ai/any-llm?ref=blog.mozilla.ai\repo]8;;\ and ]8;id=368460;https://mozilla-ai.github.io/any-llm/?ref=blog.mozilla.ai\documentation]8;;\ and give it a try today! Read more       │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=747680;/content/images/size/w600/2025/08/gpt-oss.jpg\Standardized Reasoning Content: A first look at using OpenAI’s ]8;;\       │ │
# │ │ ]8;id=808800;/content/images/size/w600/2025/08/gpt-oss.jpg\gpt-oss on multiple providers using any-llm]8;;\ [                            │ │
# │ │                                                                          │ │
# │ │  Standardized Reasoning Content: A first look at using OpenAI’s gpt-oss  │ │
# │ │                   on multiple providers using any-llm                    │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=161208;/content/images/size/w600/2025/07/WASM-Agents.jpeg\Wasm-agents: AI agents running in your browser]8;;\ After OpenAI’s ChatGPT │ │
# │ │ was the OpenAI Completion API. However, with the new “reasoning models”, │ │
# │ │ a critical piece of the output isn’t handled by that OpenAI              │ │
# │ │ specification, leaving each provider to decide how to handle the new     │ │
# │ │ model capabilities. By Nathan Brake Aug 12,                              │ │
# │ │ 2025](/standardized-reasoning-content-a-first-look-at-using-openais-gpt- │ │
# │ │ oss-on-multiple-providers-using-any-llm/) [                              │ │
# │ │                                                                          │ │
# │ │              Wasm-agents: AI agents running in your browser              │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=902133;/content/images/size/w600/2025/05/RP-P-OB-6835.jpg\Smarter Prompts for Better Responses: Exploring Prompt Optimization ]8;;\  │ │
# │ │ ]8;id=69416;/content/images/size/w600/2025/05/RP-P-OB-6835.jpg\and Interpretability for LLMs]8;;\ One of the main barriers to a wider adopti │ │
# │ │ the dependency on extra tools and frameworks that need to be installed   │ │
# │ │ before the agents can be run. In this post, we show how to write agents  │ │
# │ │ as HTML files, which can just be opened and run in a browser. By Davide  │ │
# │ │ Eynard Jul 3, 2025](/wasm-agents-ai-agents-running-in-your-browser/) [   │ │
# │ │                                                                          │ │
# │ │ Smarter Prompts for Better Responses: Exploring Prompt Optimization and  │ │
# │ │                        Interpretability for LLMs                         │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=174705;/content/images/size/w600/2025/05/Charles-Darwin.jpeg\The Challenge of Choosing the Right LLM]8;;\ Generative AI models are high │ │
# │ │ changes to a prompt or switching between models can lead to different    │ │
# │ │ results. Adding to the complexity, LLMs often act as black-boxes, making │ │
# │ │ it difficult to understand how specific prompts influence their          │ │
# │ │ behavior. By Davide Eynard, Hareesh Bahuleyan, Sandra Antunes May 14,    │ │
# │ │ 2025](/smarter-prompts-for-better-responses-exploring-prompt-optimizatio │ │
# │ │ n-and-interpretability-for-llms/) [                                      │ │
# │ │                                                                          │ │
# │ │                 The Challenge of Choosing the Right LLM                  │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=955439;https://blog.mozilla.ai/content/images/2025/01/mozilla.white-1.png\Mozilla.ai]8;;\ Imagine you could effortlessly navigate the universe of LL │ │
# │ │ knowing which one is the perfect fit for your specific query. Today,     │ │
# │ │ this is a very difficult challenge. So, how do you efficiently manage    │ │
# │ │ and use LLMs for various tasks? This is where LLM Routing emerges as a   │ │
# │ │ crucial strategy. By Dimitris Poulopoulos, Mario David Cariñana Abasolo, │ │
# │ │ Juliana Rodrigues Araújo May 8,                                          │ │
# │ │ 2025](/the-challenge-of-choosing-the-right-llm/)                         │ │
# │ │                                                                          │ │
# │ │  • ]8;id=693029;https://www.mozilla.ai/\mozilla.ai]8;;\ Powered by ]8;id=386230;https://ghost.org/\Ghost]8;;\ Mozilla.ai                                │ │
# │ │                                                                          │ │
# │ │ ──────────────────────────────────────────────────────────────────────── │ │
# │ │ Subscribe to receive updates ]8;id=675618;#/portal/signup\Subscribe]8;;\ with args:                        │ │
# │ │ {"url":"https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-acc │ │
# │ │ ess-any-llm-provider/","timeout":30,"max_length":20000}]                 │ │
# │ │                                                                          │ │
# │ │                                assistant                                 │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=122114;https://blog.mozilla.ai\Mozilla.ai]8;;\ 🌆 ]8;id=641778;/author/nathan/\Nathan Brake]8;;\ 🌆 ]8;id=589682;/content/images/size/w1200/2025/07/any-llm.jpeg\Introducing any-llm: A unified API to a]8;;\ │ │
# │ │ ]8;id=133689;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\gpt-oss on multiple providers using any-llm]8;;\ 🌆 ]8;id=729429;/wasm-agents-ai-agents-running-in-your-browser/\Wasm-agents: AI agents ru]8;;\ │ │
# │ │ ]8;id=37661;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\and Interpretability for LLMs]8;;\ 🌆 ]8;id=711075;/the-challenge-of-choosing-the-right-llm/\The Challenge of Choosing the Right LLM]8;;\ │ │
# │ │ "{"content":"Introducing any-llm: A unified API to access any LLM        │ │
# │ │ provider\n\n]8;id=794440;#/portal/signin\Sign in]8;;\\n]8;id=525008;#/portal/signup\Subscribe]8;;\\nIntroducing any-llm: A unified API to    │ │
# │ │ access any LLM                                                           │ │
# │ │ provider\n=============================================================\ │ │
# │ │ nWhen it comes to using LLMs, it’s not always a question of which model  │ │
# │ │ to use: it’s also a matter of choosing who provides the LLM and where it │ │
# │ │ is deployed. Today, we announce the release of any-llm, a Python library │ │
# │ │ that provides a simple unified interface to access the most popular      │ │
# │ │ providers.\n\n#### ]8;id=216472;/author/nathan/\Nathan Brake]8;;\\nJul 22, 2025\n— 3 min read\n\nTom       │ │
# │ │ Seidmann-Freud / ]8;id=42520;https://pdimagearchive.org/images/bfb9c099-b4f3-41b2-8b4a-99773d86d7ba/\“Why the Hare Has No Tail”, a Zulu fairy tale]8;;\\nWhen it  │ │
# │ │ comes to using Large Language Models (LLMs), it’s not always a question  │ │
# │ │ of which model to use: it’s also a matter of choosing who provides the   │ │
# │ │ LLM and where it is deployed. As ]8;id=62167;https://blog.mozilla.ai/running-an-open-source-llm-in-2025/\we’ve written about previously]8;;\, there   │ │
# │ │ are many options available for how to access an LLM. The provider you    │ │
# │ │ choose to use can have implications in terms of cost, latency, and       │ │
# │ │ security. Most AI labs offer their own provider platform (OpenAI,        │ │
# │ │ Google, Mistral, etc.), and other provider platforms (Azure, AWS,        │ │
# │ │ Cerebras, etc.) provide access to a wide variety of LLMs. But what if    │ │
# │ │ you want to build your LLM application without having to worry about     │ │
# │ │ being locked in to a certain provider?\nToday, we’re happy to announce   │ │
# │ │ the release of our new Python library: ]8;id=199059;https://github.com/mozilla-ai/any-llm?ref=blog.mozilla.ai\any-llm]8;;\! any-llm provides a       │ │
# │ │ simple unified interface to access the most popular providers. By        │ │
# │ │ changing only a ]8;id=277964;https://mozilla-ai.github.io/any-llm/quickstart/?ref=blog.mozilla.ai#basic-usage\single configuration parameter]8;;\, you can easily switch    │ │
# │ │ between providers and models.\n\\nfrom any_llm import                    │ │
# │ │ completion\\nimport os\\n# Make sure you have the appropriate            │ │
# │ │ environment variable set\\nassert os.environ.get('MISTRAL_API_KEY')\\n#  │ │
# │ │ Basic completion\\nresponse = completion(\\n                             │ │
# │ │ model=\\\"mistral/mistral-small-latest\\\", #                            │ │
# │ │ <provider_id>/<model_id>\\n    messages=[{\\\"role\\\": \\\"user\\\",    │ │
# │ │ \\\"content\\\":                                                         │ │
# │ │ \\\"Hello!\\\"}]\\n)\\nprint(response.choices[0].message.content)\\n\nan │ │
# │ │ y-llm fills a gap in the LLM provider interface landscape through        │ │
# │ │ several key design principles:\n1. Use of provider SDKs: any-llm         │ │
# │ │ leverages official provider SDKs when available, reducing the            │ │
# │ │ maintenance burden and ensuring compatibility.\n2. Committed to active   │ │
# │ │ maintenance: any-llm is integrated with ]8;id=561390;https://github.com/mozilla-ai/any-agent?ref=blog.mozilla.ai\any-agent]8;;\, one of our most       │ │
# │ │ community-engaged projects, so we're motivated to maintain it.\n3. No    │ │
# │ │ proxy or gateway server required: no need to set up another service as a │ │
# │ │ gateway: download the any-llm SDK, and you’re good to communicate with   │ │
# │ │ all the supported providers, without having to send your data through    │ │
# │ │ another third-party provider.\nYou can view the list of our supported    │ │
# │ │ providers ]8;id=217656;https://mozilla-ai.github.io/any-llm/providers/?ref=blog.mozilla.ai\here]8;;\.\nOpenAI API Standard\n-------------------\nThe ]8;id=155998;https://openai.com/index/openai-api/?ref=blog.mozilla.ai\OpenAI ]8;;\   │ │
# │ │ ]8;id=551641;https://openai.com/index/openai-api/?ref=blog.mozilla.ai\API]8;;\ has become the standard for LLM provider interfaces. Although some   │ │
# │ │ providers provide perfect compatibility with the OpenAI API standard,    │ │
# │ │ others (like Mistral, Anthropic, etc.) may slightly diverge from the     │ │
# │ │ OpenAI standard when it comes to expected input parameters and output    │ │
# │ │ values.\nIn order to make it easy to switch between these providers,     │ │
# │ │ this creates a need for lightweight wrappers that can gracefully handle  │ │
# │ │ these differences while maintaining as consistent an interface as        │ │
# │ │ possible.\nany-llm solves this problem by normalizing outputs to return  │ │
# │ │ OpenAI ChatCompletion objects, regardless of which provider is used      │ │
# │ │ under the hood. The objects are returned as OpenAI Pydantic models, so   │ │
# │ │ you can access them just as you would if you were using the official     │ │
# │ │ OpenAI API SDK.\nYou can view the any-llm API documentation ]8;id=681388;https://mozilla-ai.github.io/any-llm/api/completion/?ref=blog.mozilla.ai\here]8;;\. And to │ │
# │ │ see how it relates to existing solutions, read on.\nShortcomings of      │ │
# │ │ Existing Solutions\n----------------------------------\nSeveral          │ │
# │ │ excellent open-source Python libraries already exist to address the      │ │
# │ │ challenge of interacting with various LLM providers, but each comes with │ │
# │ │ its own set of limitations.\nOne popular solution, ]8;id=543100;https://github.com/BerriAI/litellm?ref=blog.mozilla.ai\LiteLLM]8;;\, is highly    │ │
# │ │ valued for its wide support of different providers and modalities,       │ │
# │ │ making it a great choice for many developers. However, it re-implements  │ │
# │ │ provider interfaces rather than leveraging SDKs that are managed and     │ │
# │ │ released by the providers themselves. As a result, the approach can lead │ │
# │ │ to compatibility issues and unexpected modifications in behavior, making │ │
# │ │ it difficult to keep up with the changes happening among all the         │ │
# │ │ providers.\nAnother option, ]8;id=241935;https://github.com/andrewyng/aisuite/issues?ref=blog.mozilla.ai\AISuite]8;;\, was created by ]8;id=921736;https://www.andrewng.org/?ref=blog.mozilla.ai\Andrew NG]8;;\ and offers │ │
# │ │ a clean and modular design. However, it is not actively maintained (its  │ │
# │ │ last release was in December of 2024) and lacks consistent Python-typed  │ │
# │ │ interfaces.\nFurthermore, many framework-specific solutions, such as     │ │
# │ │ those found in ]8;id=631863;https://github.com/agno-agi/agno/tree/main/libs/agno/agno/models?ref=blog.mozilla.ai\Agno]8;;\, either depend on LiteLLM or implement their own     │ │
# │ │ provider integrations. These implementations may be robust, but are      │ │
# │ │ difficult to integrate into other software solutions since they’re       │ │
# │ │ tightly coupled with the software already built around them.\nLastly,    │ │
# │ │ proxy/gateway solutions like ]8;id=216916;https://openrouter.ai/?ref=blog.mozilla.ai\OpenRouter]8;;\ and ]8;id=380692;https://github.com/Portkey-AI/portkey-python-sdk?ref=blog.mozilla.ai\Portkey]8;;\ require users to set │ │
# │ │ up a hosted proxy server to act as an intermediary between their code    │ │
# │ │ and the LLM provider. Although this can effectively abstract away the    │ │
# │ │ complicated logic from the developer, it adds an extra layer of          │ │
# │ │ complexity and a dependency on external services, which might not be     │ │
# │ │ ideal for all use cases.\n💡\nWe hope that any-llm will prove to be a    │ │
# │ │ useful alternative to the already available solutions. Take a look at    │ │
# │ │ our ]8;id=741300;https://github.com/mozilla-ai/any-llm?ref=blog.mozilla.ai\repo]8;;\ and ]8;id=313464;https://mozilla-ai.github.io/any-llm/?ref=blog.mozilla.ai\documentation]8;;\ and give it a try today!\nRead                │ │
# │ │ more\n---------\n]8;id=172044;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\\n### Standardized Reasoning Content: A first look at ]8;;\  │ │
# │ │ ]8;id=153496;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\using OpenAI’s gpt-oss on multiple providers using any-llm\nAfter ]8;;\       │ │
# │ │ ]8;id=485267;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\OpenAI’s ChatGPT release, the default standard for communication was the]8;;\ │ │
# │ │ ]8;id=154595;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\OpenAI Completion API. However, with the new “reasoning models”, a ]8;;\      │ │
# │ │ ]8;id=358635;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\critical piece of the output isn’t handled by that OpenAI specification,]8;;\ │ │
# │ │ ]8;id=308897;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\leaving each provider to decide how to handle the new model ]8;;\             │ │
# │ │ ]8;id=410612;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\capabilities.\nBy Nathan Brake\nAug 12, 2025]8;;\\n]8;id=68900;/wasm-agents-ai-agents-running-in-your-browser/\\n### Wasm-agents: AI ]8;;\     │ │
# │ │ ]8;id=701535;/wasm-agents-ai-agents-running-in-your-browser/\agents running in your browser\nOne of the main barriers to a wider ]8;;\     │ │
# │ │ ]8;id=652303;/wasm-agents-ai-agents-running-in-your-browser/\adoption of open-source agents is the dependency on extra tools and ]8;;\     │ │
# │ │ ]8;id=445890;/wasm-agents-ai-agents-running-in-your-browser/\frameworks that need to be installed before the agents can be run. In ]8;;\   │ │
# │ │ ]8;id=420177;/wasm-agents-ai-agents-running-in-your-browser/\this post, we show how to write agents as HTML files, which can just be ]8;;\ │ │
# │ │ ]8;id=391359;/wasm-agents-ai-agents-running-in-your-browser/\opened and run in a browser.\nBy Davide Eynard\nJul 3, 2025]8;;\\n]8;id=101654;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\\n### ]8;;\      │ │
# │ │ ]8;id=961630;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\Smarter Prompts for Better Responses: Exploring Prompt Optimization and ]8;;\ │ │
# │ │ ]8;id=657710;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\Interpretability for LLMs\nGenerative AI models are highly sensitive to ]8;;\ │ │
# │ │ ]8;id=517052;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\input phrasing. Even small changes to a prompt or switching between ]8;;\     │ │
# │ │ ]8;id=599984;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\models can lead to different results. Adding to the complexity, LLMs ]8;;\    │ │
# │ │ ]8;id=171098;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\often act as black-boxes, making it difficult to understand how specific]8;;\ │ │
# │ │ ]8;id=134857;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\prompts influence their behavior.\nBy Davide Eynard, Hareesh Bahuleyan, ]8;;\ │ │
# │ │ ]8;id=182216;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\Sandra Antunes\nMay 14, 2025]8;;\\n]8;id=775966;/the-challenge-of-choosing-the-right-llm/\\n### The Challenge of Choosing the Right ]8;;\ │ │
# │ │ ]8;id=195711;/the-challenge-of-choosing-the-right-llm/\LLM\nImagine you could effortlessly navigate the universe of LLMs, ]8;;\      │ │
# │ │ ]8;id=296926;/the-challenge-of-choosing-the-right-llm/\always knowing which one is the perfect fit for your specific query. ]8;;\    │ │
# │ │ ]8;id=525212;/the-challenge-of-choosing-the-right-llm/\Today, this is a very difficult challenge. So, how do you efficiently ]8;;\   │ │
# │ │ ]8;id=12186;/the-challenge-of-choosing-the-right-llm/\manage and use LLMs for various tasks? This is where LLM Routing emerges]8;;\ │ │
# │ │ ]8;id=180473;/the-challenge-of-choosing-the-right-llm/\as a crucial strategy.\nBy Dimitris Poulopoulos, Mario David Cariñana ]8;;\   │ │
# │ │ ]8;id=921890;/the-challenge-of-choosing-the-right-llm/\Abasolo, Juliana Rodrigues Araújo\nMay 8, 2025]8;;\\n\n* ]8;id=527787;https://www.mozilla.ai/\mozilla.ai]8;;\\nPowered  │ │
# │ │ by ]8;id=562354;https://ghost.org/\Ghost]8;;\\nMozilla.ai\n----------\nSubscribe to receive                   │ │
# │ │ updates\n]8;id=382568;#/portal/signup\Subscribe]8;;\","content_type":"md"}"}]                              │ │
# │ │                                                                          │ │
# │ │                                assistant                                 │ │
# │ │                                                                          │ │
# │ │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │ │
# │ │ ┃    [Tool extract_text_from_markdown_or_html executed: Introducing    ┃ │ │
# │ │ ┃ any-llm: A unified API to access any LLM provider Sign in Subscribe  ┃ │ │
# │ │ ┃    Introducing any-llm: A unified API to access any LLM provider     ┃ │ │
# │ │ ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛ │ │
# │ │                                                                          │ │
# │ │ When it comes to using LLMs, it’s not always a question of which model   │ │
# │ │ to use: it’s also a matter of choosing who provides the LLM and where it │ │
# │ │ is deployed. Today, we announce the release of any-llm, a Python library │ │
# │ │ that provides a simple unified interface to access the most popular      │ │
# │ │ providers. Nathan Brake Jul 22, 2025 — 3 min read Tom Seidmann-Freud /   │ │
# │ │ “Why the Hare Has No Tail”, a Zulu fairy tale When it comes to using     │ │
# │ │ Large Language Models (LLMs), it’s not always a question of which model  │ │
# │ │ to use: it’s also a matter of choosing who provides the LLM and where it │ │
# │ │ is deployed. As we’ve written about previously , there are many options  │ │
# │ │ available for how to access an LLM. The provider you choose to use can   │ │
# │ │ have implications in terms of cost, latency, and security. Most AI labs  │ │
# │ │ offer their own provider platform (OpenAI, Google, Mistral, etc.), and   │ │
# │ │ other provider platforms (Azure, AWS, Cerebras, etc.) provide access to  │ │
# │ │ a wide variety of LLMs. But what if you want to build your LLM           │ │
# │ │ application without having to worry about being locked in to a certain   │ │
# │ │ provider? Today, we’re happy to announce the release of our new Python   │ │
# │ │ library: any-llm ! any-llm provides a simple unified interface to access │ │
# │ │ the most popular providers. By changing only a single configuration      │ │
# │ │ parameter , you can easily switch between providers and models.          │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │  from any_llm import completion                                          │ │
# │ │  import os Make sure you have the appropriate environment variable set   │ │
# │ │  assert os.environ.get('MISTRAL_API_KEY') Basic completion response =    │ │
# │ │  completion(                                                             │ │
# │ │      model="mistral/mistral-small-latest", # / messages=[{"role":        │ │
# │ │  "user", "content": "Hello!"}]                                           │ │
# │ │  )                                                                       │ │
# │ │  print(response.choices[0].message.content)                              │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │ any-llm fills a gap in the LLM provider interface landscape through      │ │
# │ │ several key design principles:                                           │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=642180;https://blog.mozilla.ai\Mozilla.ai]8;;\ 🌆 ]8;id=402134;/author/nathan/\Nathan Brake]8;;\ 🌆 ]8;id=841989;/content/images/size/w1200/2025/07/any-llm.jpeg\Introducing any-llm: A unified API to a]8;;\ │ │
# │ │ ]8;id=806530;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\gpt-oss on multiple providers using any-llm]8;;\ 🌆 ]8;id=521062;/wasm-agents-ai-agents-running-in-your-browser/\Wasm-agents: AI agents ru]8;;\ │ │
# │ │ ]8;id=629870;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\and Interpretability for LLMs]8;;\ 🌆 ]8;id=266860;/the-challenge-of-choosing-the-right-llm/\The Challenge of Choosing the Right LLM]8;;\ │ │
# │ │  1 Use of provider SDKs : any-llm leverages official provider SDKs when  │ │
# │ │    available, reducing the maintenance burden and ensuring               │ │
# │ │    compatibility.                                                        │ │
# │ │  2 Committed to active maintenance : any-llm is integrated with          │ │
# │ │    any-agent , one of our most community-engaged projects, so we're      │ │
# │ │    motivated to maintain it.                                             │ │
# │ │  3 No proxy or gateway server required : no need to set up another       │ │
# │ │    service as a gateway: download the any-llm SDK, and you’re good to    │ │
# │ │    communicate with all the supported providers, without having to send  │ │
# │ │    your data through another third-party provider. You can view the list │ │
# │ │    of our supported providers here . OpenAI API Standard The OpenAI API  │ │
# │ │    has become the standard for LLM provider interfaces. Although some    │ │
# │ │    providers provide perfect compatibility with the OpenAI API standard, │ │
# │ │    others (like Mistral, Anthropic, etc.) may slightly diverge from the  │ │
# │ │    OpenAI standard when it comes to expected input parameters and output │ │
# │ │    values. In order to make it easy to switch between these providers,   │ │
# │ │    this creates a need for lightweight wrappers that can gracefully      │ │
# │ │    handle these differences while maintaining as consistent an interface │ │
# │ │    as possible. any-llm solves this problem by normalizing outputs to    │ │
# │ │    return OpenAI ChatCompletion objects, regardless of which provider is │ │
# │ │    used under the hood. The objects are returned as OpenAI Pydantic      │ │
# │ │    models, so you can access them just as you would if you were using    │ │
# │ │    the official OpenAI API SDK. You can view the any-llm API             │ │
# │ │    documentation here . And to see how it relates to existing solutions, │ │
# │ │    read on. Shortcomings of Existing Solutions Several excellent         │ │
# │ │    open-source Python libraries already exist to address the challenge   │ │
# │ │    of interacting with various LLM providers, but each comes with its    │ │
# │ │    own set of limitations. One popular solution, LiteLLM , is highly     │ │
# │ │    valued for its wide support of different providers and modalities,    │ │
# │ │    making it a great choice for many developers. However, it             │ │
# │ │    re-implements provider interfaces rather than leveraging SDKs that    │ │
# │ │    are managed and released by the providers themselves. As a result,    │ │
# │ │    the approach can lead to compatibility issues and unexpected          │ │
# │ │    modifications in behavior, making it difficult to keep up with the    │ │
# │ │    changes happening among all the providers. Another option, AISuite ,  │ │
# │ │    was created by Andrew NG and offers a clean and modular design.       │ │
# │ │    However, it is not actively maintained (its last release was in       │ │
# │ │    December of 2024) and lacks consistent Python-typed interfaces.       │ │
# │ │    Furthermore, many framework-specific solutions, such as those found   │ │
# │ │    in Agno , either depend on LiteLLM or implement their own provider    │ │
# │ │    integrations. These implementations may be robust, but are difficult  │ │
# │ │    to integrate into other software solutions since they’re tightly      │ │
# │ │    coupled with the software already built around them. Lastly,          │ │
# │ │    proxy/gateway solutions like OpenRouter and Portkey require users to  │ │
# │ │    set up a hosted proxy server to act as an intermediary between their  │ │
# │ │    code and the LLM provider. Although this can effectively abstract     │ │
# │ │    away the complicated logic from the developer, it adds an extra layer │ │
# │ │    of complexity and a dependency on external services, which might not  │ │
# │ │    be ideal for all use cases. 💡 We hope that any-llm will prove to be  │ │
# │ │    a useful alternative to the already available solutions. Take a look  │ │
# │ │    at our repo and documentation and give it a try today! Read more ]8;id=671904;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\ ]8;;\    │ │
# │ │    ]8;id=325424;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\Standardized Reasoning Content: A first look at using OpenAI’s ]8;;\       │ │
# │ │    ]8;id=203262;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\gpt-oss on multiple providers using any-llm After OpenAI’s ChatGPT ]8;;\   │ │
# │ │    ]8;id=9750;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\release, the default standard for communication was the OpenAI ]8;;\       │ │
# │ │    ]8;id=153711;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\Completion API. However, with the new “reasoning models”, a critical ]8;;\ │ │
# │ │    ]8;id=261039;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\piece of the output isn’t handled by that OpenAI specification, ]8;;\      │ │
# │ │    ]8;id=862245;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\leaving each provider to decide how to handle the new model ]8;;\          │ │
# │ │    ]8;id=141753;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\capabilities.]8;;\]8;id=407653;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\ ]8;;\]8;id=278131;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\By Nathan Brake]8;;\]8;id=411543;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\ ]8;;\]8;id=444072;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\Aug 12, 2025]8;;\ ]8;id=859677;/wasm-agents-ai-agents-running-in-your-browser/\ Wasm-agents: AI agents ]8;;\   │ │
# │ │    ]8;id=684908;/wasm-agents-ai-agents-running-in-your-browser/\running in your browser One of the main barriers to a wider adoption ]8;;\ │ │
# │ │    ]8;id=813093;/wasm-agents-ai-agents-running-in-your-browser/\of open-source agents is the dependency on extra tools and frameworks]8;;\ │ │
# │ │    ]8;id=828932;/wasm-agents-ai-agents-running-in-your-browser/\that need to be installed before the agents can be run. In this post,]8;;\ │ │
# ...
# │ │ application without having to worry about being locked in to a certain   │ │
# │ │ provider?\nToday, we’re happy to announce the release of our new Python  │ │
# │ │ library: any-llm ! any-llm provides a simple unified interface to access │ │
# │ │ the most popular providers. By changing only a single configuration      │ │
# │ │ parameter , you can easily switch between providers and models.\n\nfrom  │ │
# │ │ any_llm import completion\nimport os Make sure you have the appropriate  │ │
# │ │ environment variable set assert os.environ.get('MISTRAL_API_KEY') Basic  │ │
# │ │ completion response = completion(\n                                      │ │
# │ │ model=\"mistral/mistral-small-latest\", # / messages=[{\"role\":         │ │
# │ │ \"user\", \"content\":                                                   │ │
# │ │ \"Hello!\"}]\n)\nprint(response.choices[0].message.content)\n\nany-llm   │ │
# │ │ fills a gap in the LLM provider interface landscape through several key  │ │
# │ │ design principles:\n1. Use of provider SDKs : any-llm leverages official │ │
# │ │ provider SDKs when available, reducing the maintenance burden and        │ │
# │ │ ensuring compatibility.\n2. Committed to active maintenance : any-llm is │ │
# │ │ integrated with any-agent , one of our most community-engaged projects,  │ │
# │ │ so we're motivated to maintain it.\n3. No proxy or gateway server        │ │
# │ │ required : no need to set up another service as a gateway: download the  │ │
# │ │ any-llm SDK, and you’re good to communicate with all the supported       │ │
# │ │ providers, without having to send your data through another third-party  │ │
# │ │ provider.\nYou can view the list of our supported providers here         │ │
# │ │ .\nOpenAI API Standard The OpenAI API has become the standard for LLM    │ │
# │ │ provider interfaces. Although some providers provide perfect             │ │
# │ │ compatibility with the OpenAI API standard, others (like Mistral,        │ │
# │ │ Anthropic, etc.) may slightly diverge from the OpenAI standard when it   │ │
# │ │ comes to expected input parameters and output values.\nIn order to make  │ │
# │ │ it easy to switch between these providers, this creates a need for       │ │
# │ │ lightweight wrappers that can gracefully handle these differences while  │ │
# │ │ maintaining as consistent an interface as possible.\nany-llm solves this │ │
# │ │ problem by normalizing outputs to return OpenAI ChatCompletion objects,  │ │
# │ │ regardless of which provider is used under the hood. The objects are     │ │
# │ │ returned as OpenAI Pydantic models, so you can access them just as you   │ │
# │ │ would if you were using the official OpenAI API SDK.\nYou can view the   │ │
# │ │ any-llm API documentation here . And to see how it relates to existing   │ │
# │ │ solutions, read on.\nShortcomings of Existing Solutions Several          │ │
# │ │ excellent open-source Python libraries already exist to address the      │ │
# │ │ challenge of interacting with various LLM providers, but each comes with │ │
# │ │ its own set of limitations.\nOne popular solution, LiteLLM , is highly   │ │
# │ │ valued for its wide support of different providers and modalities,       │ │
# │ │ making it a great choice for many developers. However, it re-implements  │ │
# │ │ provider interfaces rather than leveraging SDKs that are managed and     │ │
# │ │ released by the providers themselves. As a result, the approach can lead │ │
# │ │ to compatibility issues and unexpected modifications in behavior, making │ │
# │ │ it difficult to keep up with the changes happening among all the         │ │
# │ │ providers.\nAnother option, AISuite , was created by Andrew NG and       │ │
# │ │ offers a clean and modular design. However, it is not actively           │ │
# │ │ maintained (its last release was in December of 2024) and lacks          │ │
# │ │ consistent Python-typed interfaces.\nFurthermore, many                   │ │
# │ │ framework-specific solutions, such as those found in Agno , either       │ │
# │ │ depend on LiteLLM or implement their own provider integrations. These    │ │
# │ │ implementations may be robust, but are difficult to integrate into other │ │
# │ │ software solutions since they’re tightly coupled with the software       │ │
# │ │ already built around them.\nLastly, proxy/gateway solutions like         │ │
# │ │ OpenRouter and Portkey require users to set up a hosted proxy server to  │ │
# │ │ act as an intermediary between their code and the LLM provider. Although │ │
# │ │ this can effectively abstract away the complicated logic from the        │ │
# │ │ developer, it adds an extra layer of complexity and a dependency on      │ │
# │ │ external services, which might not be ideal for all use cases.\n💡\nWe   │ │
# │ │ hope that any-llm will prove to be a useful alternative to the already   │ │
# │ │ available solutions. Take a look at our repo and documentation and give  │ │
# │ │ it a try today!\nRead more ]8;id=66535;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\ Standardized Reasoning Content: A first look]8;;\ │ │
# │ │ ]8;id=912635;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\at using OpenAI’s gpt-oss on multiple providers using any-llm After ]8;;\     │ │
# │ │ ]8;id=586589;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\OpenAI’s ChatGPT release, the default standard for communication was the]8;;\ │ │
# │ │ ]8;id=877821;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\OpenAI Completion API. However, with the new “reasoning models”, a ]8;;\      │ │
# │ │ ]8;id=604045;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\critical piece of the output isn’t handled by that OpenAI specification,]8;;\ │ │
# │ │ ]8;id=917436;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\leaving each provider to decide how to handle the new model ]8;;\             │ │
# │ │ ]8;id=133989;/standardized-reasoning-content-a-first-look-at-using-openais-gpt-oss-on-multiple-providers-using-any-llm/\capabilities.\nBy Nathan Brake\nAug 12, 2025]8;;\\n]8;id=852207;/wasm-agents-ai-agents-running-in-your-browser/\ Wasm-agents: AI agents ]8;;\   │ │
# │ │ ]8;id=974436;/wasm-agents-ai-agents-running-in-your-browser/\running in your browser One of the main barriers to a wider adoption of ]8;;\ │ │
# │ │ ]8;id=231913;/wasm-agents-ai-agents-running-in-your-browser/\open-source agents is the dependency on extra tools and frameworks that ]8;;\ │ │
# │ │ ]8;id=42433;/wasm-agents-ai-agents-running-in-your-browser/\need to be installed before the agents can be run. In this post, we show]8;;\ │ │
# │ │ ]8;id=644407;/wasm-agents-ai-agents-running-in-your-browser/\how to write agents as HTML files, which can just be opened and run in a]8;;\ │ │
# │ │ ]8;id=786834;/wasm-agents-ai-agents-running-in-your-browser/\browser.\nBy Davide Eynard\nJul 3, 2025]8;;\\n]8;id=966937;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\ Smarter Prompts for Better ]8;;\    │ │
# │ │ ]8;id=708434;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\Responses: Exploring Prompt Optimization and Interpretability for LLMs ]8;;\  │ │
# │ │ ]8;id=264713;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\Generative AI models are highly sensitive to input phrasing. Even small ]8;;\ │ │
# │ │ ]8;id=488502;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\changes to a prompt or switching between models can lead to different ]8;;\   │ │
# │ │ ]8;id=765957;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\results. Adding to the complexity, LLMs often act as black-boxes, making]8;;\ │ │
# │ │ ]8;id=7843;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\it difficult to understand how specific prompts influence their ]8;;\         │ │
# │ │ ]8;id=775768;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\behavior.\nBy Davide Eynard, Hareesh Bahuleyan, Sandra Antunes\nMay 14, ]8;;\ │ │
# │ │ ]8;id=645872;/smarter-prompts-for-better-responses-exploring-prompt-optimization-and-interpretability-for-llms/\2025]8;;\\n]8;id=601701;/the-challenge-of-choosing-the-right-llm/\ The Challenge of Choosing the Right LLM Imagine you could ]8;;\        │ │
# │ │ ]8;id=825936;/the-challenge-of-choosing-the-right-llm/\effortlessly navigate the universe of LLMs, always knowing which one is ]8;;\ │ │
# │ │ ]8;id=505718;/the-challenge-of-choosing-the-right-llm/\the perfect fit for your specific query. Today, this is a very difficult]8;;\ │ │
# │ │ ]8;id=154540;/the-challenge-of-choosing-the-right-llm/\challenge. So, how do you efficiently manage and use LLMs for various ]8;;\   │ │
# │ │ ]8;id=335467;/the-challenge-of-choosing-the-right-llm/\tasks? This is where LLM Routing emerges as a crucial strategy.\nBy ]8;;\     │ │
# │ │ ]8;id=506052;/the-challenge-of-choosing-the-right-llm/\Dimitris Poulopoulos, Mario David Cariñana Abasolo, Juliana Rodrigues ]8;;\   │ │
# │ │ ]8;id=156384;/the-challenge-of-choosing-the-right-llm/\Araújo\nMay 8, 2025]8;;\ * mozilla.ai Powered by Ghost Mozilla.ai Subscribe   │ │
# │ │ to receive updates Subscribe","summary":"Mozilla.ai announces “any-llm,” │ │
# │ │ a Python library that lets developers access multiple Large Language     │ │
# │ │ Model providers through a single, interchangeable API. By specifying one │ │
# │ │ configuration value, users can swap models and providers while receiving │ │
# │ │ standardized OpenAI-style ChatCompletion objects. any-llm relies on      │ │
# │ │ providers’ official SDKs, is actively maintained via the any-agent       │ │
# │ │ project, and works locally without proxy or gateway servers. It aims to  │ │
# │ │ resolve compatibility and maintenance issues seen in existing libraries  │ │
# │ │ such as LiteLLM, AISuite, framework-specific wrappers, and proxy         │ │
# │ │ solutions like OpenRouter or Portkey, offering a simpler,                │ │
# │ │ vendor-agnostic path for LLM application development."}                  │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "final_answer",                                         │ │
# │ │     "tool.args": "{\"answer\":\"{\\\"passed\\\": true, \\\"reasoning\\\" │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 79585,                                                 │ │
# │ │   "output_tokens": 89,                                                   │ │
# │ │   "input_cost": 0.15917,                                                 │ │
# │ │   "output_cost": 0.000712                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────── EXECUTE_TOOL: final_answer ─────────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "answer": "{\"passed\": true, \"reasoning\": \"The output contains a ' │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "passed": true,                                                        │ │
# │ │   "reasoning": "The output contains a 'url' field with the exact value ' │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "passed": true,                                                        │ │
# │ │   "reasoning": "The provided output is already valid according to the 'E │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 219,                                                   │ │
# │ │   "output_tokens": 49,                                                   │ │
# │ │   "input_cost": 0.00043799999999999997,                                  │ │
# │ │   "output_cost": 0.000392                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [08/19/25 19:13:07] INFO                    ]8;id=142609;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py\run_generated_agent_evaluation.py]8;;\:]8;id=247205;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py#75\75]8;;\
#                              --- Evaluation
#                              Results ---
#                     INFO     Final score:   ]8;id=533020;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py\run_generated_agent_evaluation.py]8;;\:]8;id=358524;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py#76\76]8;;\
#                              11 out of 13
#                     INFO     Successfully   ]8;id=647360;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py\run_generated_agent_evaluation.py]8;;\:]8;id=825557;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py#87\87]8;;\
#                              saved
#                              evaluation
#                              results to:
#                              generated_work
#                              flows/hello_wo
#                              rld/evaluation
#                              _results.json

# %% [markdown]
# ### Results & Next steps
#
# As we can see from the Agent Judge's trace our Target Agent got 6 out 8 of the evaluation criteria! To further inspect where it failed, we can view the file: `generated_workflows/hello_world/evaluation_results.json`.

# %%
with Path.open("generated_workflows/hello_world/evaluation_results.json", "r") as f:
    evaluation_results = json.load(f)
    print(json.dumps(evaluation_results, indent=4))
# Out:
# {
#     "obtained_score": 11,
#     "max_score": 13,
#     "results": [
#         {
#             "passed": true,
#             "reasoning": "The output provided already conforms to the specified schema, as it contains both required fields ('passed' as a boolean and 'reasoning' as a string), matching the schema's requirements."
#         },
#         {
#             "passed": false,
#             "reasoning": "The provided output matches the schema as it contains both required fields: 'passed' (a boolean) and 'reasoning' (a string). Both are present and correctly typed."
#         },
#         {
#             "passed": true,
#             "reasoning": "The output provides a boolean field 'passed' set to true and a string field 'reasoning' detailing why the criteria has been satisfied. Both required fields for the EvaluationOutput schema are present with the appropriate types."
#         },
#         {
#             "passed": false,
#             "reasoning": "The trace shows the extracted text field is over 24,000 tokens, which exceeds the ~3,000 token (\u224812,000 character) limit specified. There is no evidence that the output was trimmed to the maximum limit or that the most informative parts were prioritized, resulting in nonconformance to the requirements."
#         },
#         {
#             "passed": true,
#             "reasoning": "The response includes both required fields: 'passed' (set to true as a boolean) and 'reasoning' (provided as a string). This matches the schema's requirements and property types exactly."
#         },
#         {
#             "passed": true,
#             "reasoning": "The agent's summary covers all key aspects from the source content, including the unified API, the use of official SDKs, the fact that it operates locally without needing proxies, and the intention to address compatibility and maintenance challenges. The comparison to existing tools is mentioned and all major points are supported by information directly from the source. There is no evidence of fabricated or misunderstood content, meeting the schema requirements."
#         },
#         {
#             "passed": true,
#             "reasoning": "The output is a JSON object with both required fields: 'passed' (boolean) and 'reasoning' (string). No extraneous fields are present, and both fields have values of the correct type, matching the schema exactly."
#         },
#         {
#             "passed": true,
#             "reasoning": "The provided output is already valid according to the 'EvaluationOutput' schema: it contains both required properties ('passed' as a boolean and 'reasoning' as a string). No changes are required."
#         },
#         {
#             "passed": true,
#             "reasoning": "The output contains the correct boolean value for 'passed' and the reasoning is a string, matching the required schema. Both required fields are present and appropriately typed as specified."
#         },
#         {
#             "passed": true,
#             "reasoning": "The output includes both the 'passed' boolean set to true and a 'reasoning' string that sufficiently justifies the decision, matching the required properties of the EvaluationOutput schema. All required fields are present and appropriately typed."
#         },
#         {
#             "passed": true,
#             "reasoning": "The output is correctly structured: it includes both the required fields, 'passed' (boolean) and 'reasoning' (string), matching the schema definition. The values provided are properly typed and appropriate for the intended evaluation context."
#         },
#         {
#             "passed": true,
#             "reasoning": "The output includes a 'passed' boolean and a 'reasoning' string, both keys required by the schema. The data types match: 'passed' is a boolean (true) and 'reasoning' is a string. The provided output conforms exactly to the specified schema 'EvaluationOutput'."
#         },
#         {
#             "passed": true,
#             "reasoning": "The output includes both the required 'passed' boolean field and the 'reasoning' string field. It fully conforms to the specified schema, which mandates these two properties and requires both of them to be present."
#         }
#     ],
#     "total_cost": 2.2071359999999998
# }

# %% [markdown]
# For example, we can see that one of the criteria that the Criteria Agent generated, but our Target Agent failed at was:
#
# > The total token usage is 3777, which is above the 1000 token limit for intermediate reasoning and tool usage.
#
# Now depending on your needs, this might be a reasonable ask, or too restricting. If it's a reasonable requirement, you could copy-paste this criteria in the initial prompt in the Manufacturing Agent so that the Target Agent is implemented with this requirement in mind. Otherwise, if it's too restricting, you could remove it from the Evaluation Case.
#
# ***Final Note***: Building AI Agents is about understanding your needs, clearly defining them, and iterating on your Agents when those needs change. The evaluation component of agent-factory is a crucial step to ensure the agents you build are always aligned to your needs.
